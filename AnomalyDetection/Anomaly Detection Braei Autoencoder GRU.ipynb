# %% [markdown]
# # Imports and constants

# %%
import os

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

import visualizer.Viewer as vw
from Metrics import compute_metrics, make_metric_plots
from models.time_series.anomaly.deep_learning.GRUAutoencoder import GRUAutoencoder
from reader.NABTimeSeriesReader import NABTimeSeriesReader

# DATASET 1: ambient_temperature_system_failure
# DATASET 2: nyc_taxi
VALIDATION_DIM = 0.19
DATASET_PATH = "data/dataset/"
DATASET = "nyc_taxi.csv"
PURE_DATA_KEY = "realKnownCause/nyc_taxi.csv"
GROUND_WINDOWS_PATH = "data/dataset/combined_windows.json"
# The number of normal samples that must lie between a normal slice and an anomaly
SAFETY_DIM = 50
MINIMUM_SLICE = 100
ALL_METRICS = True
LOAD_MODEL = False
CHECK_OVERFITTING = False
AUTOENCODER_WINDOW = 32


def preprocess(X) -> np.ndarray:
    return StandardScaler().fit_transform(X)

# %% [markdown]
# # Set seed for reproducibility

# %%
np.random.seed(57)
tf.random.set_seed(57)

# %% [markdown]
# # Load training and testing data

# %%
reader = NABTimeSeriesReader(DATASET_PATH)
all_df = reader.read(DATASET_PATH + DATASET).get_dataframe()
training, test = reader.train_test_split(train_perc=0.37).get_train_test_dataframes()

# Data used to train
data = preprocess(np.array(training["value"]).reshape((training["value"].shape[0], 1)))
data_labels = training["target"]

# Data used to test
data_test = preprocess(np.array(test["value"]).reshape((test["value"].shape[0], 1)))
data_test_labels = test["target"]

# Eliminate exceeding points
if data_test.shape[0] % AUTOENCODER_WINDOW != 0:
    remainder_points = data_test.shape[0] % AUTOENCODER_WINDOW
    
    np_data = np.array(data)
    np_data_test = np.array(data_test)
    np_data_labels = np.array(data_labels)
    np_data_test_labels = np.array(data_test_labels)
    data = np.concatenate((np_data, np_data_test[0:remainder_points]))
    data_labels = np.concatenate((np_data_labels, np_data_test_labels[0:remainder_points]))
    data_test = data_test[remainder_points:]
    data_test_labels = data_test_labels[remainder_points:]
    
    np_train = np.concatenate((np.array(training), np.array(test[:remainder_points])))
    training = pd.DataFrame(np_train, columns=training.columns)
    
    np_test = np.array(test[remainder_points:])
    test = pd.DataFrame(np_test, columns=test.columns)

# Data used to evaluate
dataframe = test.copy()
dataframe["value"] = data_test

if CHECK_OVERFITTING:
    data_test = preprocess(np.array(training["value"]).reshape(training["value"].shape[0], 1))
    data_test_labels = training["target"]
    dataframe = training.copy()
    dataframe["value"] = data_test

# %% [markdown]
# # Set slices on which to train and validate
#
# In each case we use a self-supervised approach. The models are built to be able to correctly reproduce normal samples of the data. Therefore, from the training dataset, we want to exclude all possible anomalies and their neighbouring points not to learn anomalies patterns. In such a way, we aim the model to produce big mispredictions for those points that are anomalies. Given these statements, from training and validation set we extract slices without anomalies.

# %%
# Create the slices of the trainig data
change_idx = np.where(np.array(data_labels[:-1]) != np.array(data_labels[1:]))
change_idx = np.array(change_idx) + 1
change_idx = change_idx.reshape(change_idx.shape[1])
change_idx = np.concatenate((np.array([0]), change_idx))
normal_slices = []
anomaly_slices = []
for i in range(len(change_idx)):
    start = change_idx[i]
    if i < len(change_idx) -1:
        stop = change_idx[i+1]
    else:
        stop = data.shape[0]
    
    if data_labels[change_idx[i]] == 1:
        anomaly_slices.append(slice(start, stop))
    else:
        normal_slices.append(slice(start, stop))

print("The slices before safety check: %s" % normal_slices)

for i in range(len(normal_slices)):
    start_first = False
    end_last = False
    if normal_slices[i].start == 0:
        start_first = True
    if normal_slices[i].stop == data.shape[0]:
        end_last = True
    
    if not start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)
    elif not start_first and end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop,
                                 normal_slices[i].step)
    elif start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)

print("The slices after safety check: %s" % normal_slices)
# Out:
# The slices before safety check: [slice(0, 3824, None)]
# The slices after safety check: [slice(0, 3824, None)]

# %% [markdown]
# # Computation of training and validation slices
#
# Given the slices of normal points on which we will train and validate the model, we need to compute the slices characterizing the training and the validation samples of the dataset. To do so, we will need to iterate over the normal slices to compute the number of points in it. Then, we compute the number of points required for the validation set and from this number we will compute the validation slices. However, we risk to compute slices of only 1 sample in some extreme cases. Therefore, we will control that each slice is at least of `MINIMUM_SLICE` samples.

# %%
# Gets the step (equal for all slices)
step = normal_slices[0].step if normal_slices[0].step is not None else 1
ok_normal_slices = []
tot_samples = 0
for i in range(len(normal_slices)):
    samples = int((normal_slices[i].stop - normal_slices[i].start) / step)
    if samples > MINIMUM_SLICE:
        tot_samples += samples
        ok_normal_slices.append(normal_slices[i])
        
valid_points = tot_samples * VALIDATION_DIM
training_slices = []
validation_slices = []
tot_valid = 0
for i in reversed(range(len(ok_normal_slices))):
    if tot_valid >= valid_points:
        training_slices.append(ok_normal_slices[i])
    else:
        samples = int((ok_normal_slices[i].stop - ok_normal_slices[i].start) / step)
        needed_points = valid_points - tot_valid

        if samples < needed_points:
            validation_slices.append(ok_normal_slices[i])
        else:
            train_stop = int(ok_normal_slices[i].stop - needed_points * step)
            slice_train = slice(ok_normal_slices[i].start,
                                train_stop,
                                ok_normal_slices[i].step)
            slice_valid = slice(train_stop,
                                ok_normal_slices[i].stop,
                                ok_normal_slices[i].step)
            
            # If points are enough, they are added to lists
            if (slice_train.stop - slice_train.start) / step >= MINIMUM_SLICE:
                training_slices.append(slice_train)
            if (slice_valid.stop - slice_valid.start) / step >= MINIMUM_SLICE:
                validation_slices.append(slice_valid)
                
            # Since in this else we enter only at the last slice, set up to exit in case minimum
            # slice is not reached
            tot_valid = valid_points + 1
            
training_slices.reverse()
validation_slices.reverse()

print("The training slices are: %s" % training_slices)
print("The validation slices are: %s" % validation_slices)
# Out:
# The training slices are: [slice(0, 3097, None)]
# The validation slices are: [slice(3097, 3824, None)]

# %% [markdown]
# # Load or fit the model

# %%
model = GRUAutoencoder(window=AUTOENCODER_WINDOW,
                       max_epochs=500,
                       batch_size=32,
                       extend_not_multiple=True,
                       filename="nyc_ae_gru")
if LOAD_MODEL:
    model.load_model("data/nn_models/nyc_ae_gru")
else:
    model.fit(data, training_slices, validation_slices, data_labels)
# Out:
# [2022/05/17 18:33:14] WARNING: Data will be modified to match the window size, note that the input must be a multiple of the window size for autoencoders. This is just a comfort utility. You can ignore this warning if no other warnings regarding the training set pop up.
# [2022/05/17 18:33:14] WARNING: On 1th training slice, 25 points have been lost
# [2022/05/17 18:33:14] WARNING: On 1th validation slice, 23 points have been lost
# Model: "gru_autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 32, 1)]           0
#
#  encoder_gru_1 (GRU)         (None, 32, 128)           50304
#
#  encoder_gru_2 (GRU)         (None, 64)                37248
#
#  repeat_vector (RepeatVector  (None, 32, 64)           0
#  )
#
#  decoder_gru_1 (GRU)         (None, 32, 64)            24960
#
#  decoder_gru_2 (GRU)         (None, 32, 128)           74496
#
#  time_distributed (TimeDistr  (None, 32, 1)            129
#  ibuted)
#
# =================================================================
# Total params: 187,137
# Trainable params: 187,137
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 76/76 [==============================] - 12s 77ms/step - loss: 0.7126 - mean_squared_error: 0.7126 - val_loss: 0.4053 - val_mean_squared_error: 0.4053 - lr: 0.0010
# Epoch 2/500
# 76/76 [==============================] - 4s 52ms/step - loss: 0.2438 - mean_squared_error: 0.2438 - val_loss: 0.1207 - val_mean_squared_error: 0.1207 - lr: 0.0010
# Epoch 3/500
# 76/76 [==============================] - 4s 52ms/step - loss: 0.1153 - mean_squared_error: 0.1153 - val_loss: 0.0858 - val_mean_squared_error: 0.0858 - lr: 0.0010
# Epoch 4/500
# 76/76 [==============================] - 4s 52ms/step - loss: 0.0836 - mean_squared_error: 0.0836 - val_loss: 0.0594 - val_mean_squared_error: 0.0594 - lr: 0.0010
# Epoch 5/500
# 76/76 [==============================] - 4s 51ms/step - loss: 0.0747 - mean_squared_error: 0.0747 - val_loss: 0.0533 - val_mean_squared_error: 0.0533 - lr: 0.0010
# Epoch 6/500
# 76/76 [==============================] - 4s 51ms/step - loss: 0.0666 - mean_squared_error: 0.0666 - val_loss: 0.0460 - val_mean_squared_error: 0.0460 - lr: 0.0010
# Epoch 7/500
# 76/76 [==============================] - 4s 52ms/step - loss: 0.0665 - mean_squared_error: 0.0665 - val_loss: 0.0438 - val_mean_squared_error: 0.0438 - lr: 0.0010
# Epoch 8/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0592 - mean_squared_error: 0.0592 - val_loss: 0.0437 - val_mean_squared_error: 0.0437 - lr: 0.0010
# Epoch 9/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0548 - mean_squared_error: 0.0548 - val_loss: 0.0474 - val_mean_squared_error: 0.0474 - lr: 0.0010
# Epoch 10/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0534 - mean_squared_error: 0.0534 - val_loss: 0.0373 - val_mean_squared_error: 0.0373 - lr: 0.0010
# Epoch 11/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0462 - mean_squared_error: 0.0462 - val_loss: 0.0357 - val_mean_squared_error: 0.0357 - lr: 0.0010
# Epoch 12/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0445 - mean_squared_error: 0.0445 - val_loss: 0.0329 - val_mean_squared_error: 0.0329 - lr: 0.0010
# Epoch 13/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0455 - mean_squared_error: 0.0455 - val_loss: 0.0369 - val_mean_squared_error: 0.0369 - lr: 0.0010
# Epoch 14/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0385 - mean_squared_error: 0.0385 - val_loss: 0.0293 - val_mean_squared_error: 0.0293 - lr: 0.0010
# Epoch 15/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0326 - mean_squared_error: 0.0326 - val_loss: 0.0302 - val_mean_squared_error: 0.0302 - lr: 0.0010
# Epoch 16/500
# 76/76 [==============================] - 4s 57ms/step - loss: 0.0338 - mean_squared_error: 0.0338 - val_loss: 0.0360 - val_mean_squared_error: 0.0360 - lr: 0.0010
# Epoch 17/500
# 76/76 [==============================] - 5s 65ms/step - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.0259 - val_mean_squared_error: 0.0259 - lr: 0.0010
# Epoch 18/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0255 - val_mean_squared_error: 0.0255 - lr: 0.0010
# Epoch 19/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0264 - mean_squared_error: 0.0264 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - lr: 0.0010
# Epoch 20/500
# 76/76 [==============================] - 5s 72ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0249 - val_mean_squared_error: 0.0249 - lr: 0.0010
# Epoch 21/500
# 76/76 [==============================] - 6s 76ms/step - loss: 0.0262 - mean_squared_error: 0.0262 - val_loss: 0.0251 - val_mean_squared_error: 0.0251 - lr: 0.0010
# Epoch 22/500
# 76/76 [==============================] - 6s 75ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - lr: 0.0010
# Epoch 23/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0253 - mean_squared_error: 0.0253 - val_loss: 0.0239 - val_mean_squared_error: 0.0239 - lr: 0.0010
# Epoch 24/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0242 - val_mean_squared_error: 0.0242 - lr: 0.0010
# Epoch 25/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0227 - mean_squared_error: 0.0227 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 26/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - lr: 0.0010
# Epoch 27/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0219 - val_mean_squared_error: 0.0219 - lr: 0.0010
# Epoch 28/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0207 - mean_squared_error: 0.0207 - val_loss: 0.0382 - val_mean_squared_error: 0.0382 - lr: 0.0010
# Epoch 29/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0185 - val_mean_squared_error: 0.0185 - lr: 0.0010
# Epoch 30/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0459 - val_mean_squared_error: 0.0459 - lr: 0.0010
# Epoch 31/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0214 - mean_squared_error: 0.0214 - val_loss: 0.0172 - val_mean_squared_error: 0.0172 - lr: 0.0010
# Epoch 32/500
# 76/76 [==============================] - 4s 58ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - lr: 0.0010
# Epoch 33/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0181 - val_mean_squared_error: 0.0181 - lr: 0.0010
# Epoch 34/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0162 - val_mean_squared_error: 0.0162 - lr: 0.0010
# Epoch 35/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0170 - val_mean_squared_error: 0.0170 - lr: 0.0010
# Epoch 36/500
# 76/76 [==============================] - 5s 59ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0171 - val_mean_squared_error: 0.0171 - lr: 0.0010
# Epoch 37/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - lr: 0.0010
# Epoch 38/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0156 - val_mean_squared_error: 0.0156 - lr: 0.0010
# Epoch 39/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0138 - mean_squared_error: 0.0138 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - lr: 0.0010
# Epoch 40/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0164 - mean_squared_error: 0.0164 - val_loss: 0.0174 - val_mean_squared_error: 0.0174 - lr: 0.0010
# Epoch 41/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0139 - mean_squared_error: 0.0139 - val_loss: 0.0165 - val_mean_squared_error: 0.0165 - lr: 0.0010
# Epoch 42/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0285 - val_mean_squared_error: 0.0285 - lr: 0.0010
# Epoch 43/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0189 - val_mean_squared_error: 0.0189 - lr: 0.0010
# Epoch 44/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0168 - val_mean_squared_error: 0.0168 - lr: 0.0010
# Epoch 45/500
# 76/76 [==============================] - 5s 70ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - lr: 0.0010
# Epoch 46/500
# 76/76 [==============================] - 7s 90ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - lr: 0.0010
# Epoch 47/500
# 76/76 [==============================] - 5s 72ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0156 - val_mean_squared_error: 0.0156 - lr: 0.0010
# Epoch 48/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - lr: 0.0010
# Epoch 49/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0155 - val_mean_squared_error: 0.0155 - lr: 0.0010
# Epoch 50/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0122 - mean_squared_error: 0.0122 - val_loss: 0.0164 - val_mean_squared_error: 0.0164 - lr: 0.0010
# Epoch 51/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - lr: 0.0010
# Epoch 52/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0120 - mean_squared_error: 0.0120 - val_loss: 0.0164 - val_mean_squared_error: 0.0164 - lr: 0.0010
# Epoch 53/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - lr: 0.0010
# Epoch 54/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - lr: 0.0010
# Epoch 55/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0159 - val_mean_squared_error: 0.0159 - lr: 0.0010
# Epoch 56/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - lr: 0.0010
# Epoch 57/500
# 76/76 [==============================] - 5s 71ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0158 - val_mean_squared_error: 0.0158 - lr: 0.0010
# Epoch 58/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - lr: 0.0010
# Epoch 59/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0111 - mean_squared_error: 0.0111 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - lr: 0.0010
# Epoch 60/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - lr: 0.0010
# Epoch 61/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - lr: 0.0010
# Epoch 62/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - lr: 0.0010
# Epoch 63/500
# 76/76 [==============================] - 5s 69ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0150 - val_mean_squared_error: 0.0150 - lr: 0.0010
# Epoch 64/500
# 76/76 [==============================] - 6s 79ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - lr: 0.0010
# Epoch 65/500
# 76/76 [==============================] - 5s 72ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0137 - val_mean_squared_error: 0.0137 - lr: 0.0010
# Epoch 66/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0114 - mean_squared_error: 0.0114 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - lr: 0.0010
# Epoch 67/500
# 76/76 [==============================] - 4s 58ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - lr: 0.0010
# Epoch 68/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - lr: 0.0010
# Epoch 69/500
# 76/76 [==============================] - 4s 53ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - lr: 0.0010
# Epoch 70/500
# 76/76 [==============================] - 5s 65ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - lr: 0.0010
# Epoch 71/500
# 76/76 [==============================] - 4s 57ms/step - loss: 0.0100 - mean_squared_error: 0.0100 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - lr: 0.0010
# Epoch 72/500
# 76/76 [==============================] - 6s 79ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0129 - val_mean_squared_error: 0.0129 - lr: 0.0010
# Epoch 73/500
# 76/76 [==============================] - 6s 73ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - lr: 0.0010
# Epoch 74/500
# 76/76 [==============================] - 6s 73ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - lr: 0.0010
# Epoch 75/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - lr: 0.0010
# Epoch 76/500
# 76/76 [==============================] - 5s 66ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - lr: 0.0010
# Epoch 77/500
# 76/76 [==============================] - 6s 74ms/step - loss: 0.0112 - mean_squared_error: 0.0112 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - lr: 0.0010
# Epoch 78/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0085 - mean_squared_error: 0.0085 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - lr: 0.0010
# Epoch 79/500
# 76/76 [==============================] - 5s 66ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - lr: 0.0010
# Epoch 80/500
# 76/76 [==============================] - 5s 65ms/step - loss: 0.0090 - mean_squared_error: 0.0090 - val_loss: 0.0128 - val_mean_squared_error: 0.0128 - lr: 0.0010
# Epoch 81/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0095 - mean_squared_error: 0.0095 - val_loss: 0.0139 - val_mean_squared_error: 0.0139 - lr: 0.0010
# Epoch 82/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0144 - val_mean_squared_error: 0.0144 - lr: 0.0010
# Epoch 83/500
# 76/76 [==============================] - 5s 67ms/step - loss: 0.0123 - mean_squared_error: 0.0123 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - lr: 0.0010
# Epoch 84/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - lr: 0.0010
# Epoch 85/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - lr: 0.0010
# Epoch 86/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - lr: 0.0010
# Epoch 87/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0119 - mean_squared_error: 0.0119 - val_loss: 0.0170 - val_mean_squared_error: 0.0170 - lr: 0.0010
# Epoch 88/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - lr: 0.0010
# Epoch 89/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - lr: 0.0010
# Epoch 90/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0109 - mean_squared_error: 0.0109 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - lr: 0.0010
# Epoch 91/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - lr: 0.0010
# Epoch 92/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - lr: 0.0010
# Epoch 93/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0107 - val_mean_squared_error: 0.0107 - lr: 0.0010
# Epoch 94/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - lr: 0.0010
# Epoch 95/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - lr: 0.0010
# Epoch 96/500
# 76/76 [==============================] - 5s 66ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - lr: 0.0010
# Epoch 97/500
# 76/76 [==============================] - 5s 65ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - lr: 0.0010
# Epoch 98/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - lr: 0.0010
# Epoch 99/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - lr: 0.0010
# Epoch 100/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - lr: 0.0010
# Epoch 101/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - lr: 0.0010
# Epoch 102/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0197 - val_mean_squared_error: 0.0197 - lr: 0.0010
# Epoch 103/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - lr: 0.0010
# Epoch 104/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - lr: 0.0010
# Epoch 105/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - lr: 0.0010
# Epoch 106/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - lr: 0.0010
# Epoch 107/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - lr: 0.0010
# Epoch 108/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 0.0010
# Epoch 109/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - lr: 0.0010
# Epoch 110/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - lr: 0.0010
# Epoch 111/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0140 - val_mean_squared_error: 0.0140 - lr: 0.0010
# Epoch 112/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - lr: 0.0010
# Epoch 113/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - lr: 0.0010
# Epoch 114/500
# 76/76 [==============================] - 5s 71ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - lr: 0.0010
# Epoch 115/500
# 76/76 [==============================] - 6s 81ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - lr: 0.0010
# Epoch 116/500
# 76/76 [==============================] - 6s 78ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - lr: 0.0010
# Epoch 117/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - lr: 0.0010
# Epoch 118/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0106 - val_mean_squared_error: 0.0106 - lr: 0.0010
# Epoch 119/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - lr: 0.0010
# Epoch 120/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0138 - val_mean_squared_error: 0.0138 - lr: 0.0010
# Epoch 121/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - lr: 0.0010
# Epoch 122/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - lr: 0.0010
# Epoch 123/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0077 - mean_squared_error: 0.0077 - val_loss: 0.0110 - val_mean_squared_error: 0.0110 - lr: 0.0010
# Epoch 124/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - lr: 0.0010
# Epoch 125/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - lr: 0.0010
# Epoch 126/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0105 - val_mean_squared_error: 0.0105 - lr: 0.0010
# Epoch 127/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0142 - val_mean_squared_error: 0.0142 - lr: 0.0010
# Epoch 128/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - lr: 0.0010
# Epoch 129/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - lr: 0.0010
# Epoch 130/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0111 - val_mean_squared_error: 0.0111 - lr: 0.0010
# Epoch 131/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - lr: 0.0010
# Epoch 132/500
# 76/76 [==============================] - 5s 61ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - lr: 0.0010
# Epoch 133/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0158 - val_mean_squared_error: 0.0158 - lr: 0.0010
# Epoch 134/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - lr: 0.0010
# Epoch 135/500
# 76/76 [==============================] - 5s 67ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0102 - val_mean_squared_error: 0.0102 - lr: 0.0010
# Epoch 136/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - lr: 0.0010
# Epoch 137/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - lr: 0.0010
# Epoch 138/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0109 - val_mean_squared_error: 0.0109 - lr: 0.0010
# Epoch 139/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0245 - val_mean_squared_error: 0.0245 - lr: 0.0010
# Epoch 140/500
# 76/76 [==============================] - 6s 75ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - lr: 0.0010
# Epoch 141/500
# 76/76 [==============================] - 5s 65ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - lr: 0.0010
# Epoch 142/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0112 - val_mean_squared_error: 0.0112 - lr: 0.0010
# Epoch 143/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - lr: 0.0010
# Epoch 144/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0132 - val_mean_squared_error: 0.0132 - lr: 0.0010
# Epoch 145/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - lr: 0.0010
# Epoch 146/500
# 76/76 [==============================] - 4s 57ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - lr: 0.0010
# Epoch 147/500
# 76/76 [==============================] - 5s 66ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0108 - val_mean_squared_error: 0.0108 - lr: 0.0010
# Epoch 148/500
# 76/76 [==============================] - 5s 59ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0154 - val_mean_squared_error: 0.0154 - lr: 0.0010
# Epoch 149/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0147 - mean_squared_error: 0.0147 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - lr: 0.0010
# Epoch 150/500
# 76/76 [==============================] - 4s 58ms/step - loss: 0.0093 - mean_squared_error: 0.0093 - val_loss: 0.0103 - val_mean_squared_error: 0.0103 - lr: 0.0010
# Epoch 151/500
# 76/76 [==============================] - 4s 57ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - lr: 0.0010
# Epoch 152/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0098 - val_mean_squared_error: 0.0098 - lr: 0.0010
# Epoch 153/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0099 - val_mean_squared_error: 0.0099 - lr: 0.0010
# Epoch 154/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0100 - val_mean_squared_error: 0.0100 - lr: 0.0010
# Epoch 155/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0096 - val_mean_squared_error: 0.0096 - lr: 0.0010
# Epoch 156/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0097 - val_mean_squared_error: 0.0097 - lr: 0.0010
# Epoch 157/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-04
# Epoch 158/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 159/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-04
# Epoch 160/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-04
# Epoch 161/500
# 76/76 [==============================] - 4s 58ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-04
# Epoch 162/500
# 76/76 [==============================] - 4s 58ms/step - loss: 0.0037 - mean_squared_error: 0.0037 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 163/500
# 76/76 [==============================] - 4s 57ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 164/500
# 76/76 [==============================] - 4s 57ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 165/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-04
# Epoch 166/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 167/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 168/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-04
# Epoch 169/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 170/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-04
# Epoch 171/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 172/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 173/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 174/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 175/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 176/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-04
# Epoch 177/500
# 76/76 [==============================] - 4s 53ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0092 - val_mean_squared_error: 0.0092 - lr: 1.0000e-04
# Epoch 178/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 179/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 180/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 181/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 182/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 183/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 184/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 185/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 186/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 187/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 188/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05
# Epoch 189/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0091 - val_mean_squared_error: 0.0091 - lr: 1.0000e-05

# %% [markdown]
# # Compute labels and scores

# %%
true_labels = np.asarray(data_test_labels, dtype=np.intc)
labels = model.predict(data, data_test)
scores = model.anomaly_score(data, data_test)
perc = np.sum(labels) / labels.shape[0]

# %% [markdown]
# # Evaluation metrics for anomaly detection

# %%
compute_metrics(true_labels, scores, labels, compute_roc_auc=not CHECK_OVERFITTING, only_roc_auc=False)
# Out:
# ACCURACY SCORE:  0.9833743842364532
# PRECISION SCORE:  0.018691588785046728
# RECALL SCORE:  0.4
# F1 SCORE:  0.03571428571428571
# AVERAGE PRECISION SCORE:  0.06303001840413927
# PRECISION-RECALL AUC SCORE:  0.03539923718033598
# AUROC SCORE:  0.9114158065013095

# %% [markdown]
# # Confusion matrix

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, labels)
vw.plot_confusion_matrix(confusion_matrix)

# %% [markdown]
# # ROC curve

# %%
vw.plot_roc_curve(true_labels, scores)

# %% [markdown]
# # Precision-recall curve

# %%
vw.plot_precision_recall_curve(true_labels, scores)

# %% [markdown]
# # Assigned labels

# %%
vw.plot_univariate_time_series_predictions(dataframe, labels)

# %% [markdown]
# # Assigned scores

# %%
vw.plot_univariate_time_series_predictions(dataframe, scores)

# %% [markdown]
# # Data and predictions

# %%
predictions = model.predict_time_series(data[validation_slices[0]], data_test)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=True)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=False)

# %% [markdown]
# # Anomalies predictions as red dots

# %%
bars = vw.get_bars_indices_on_test_df(all_df,
                                      dataframe,
                                      PURE_DATA_KEY,
                                      GROUND_WINDOWS_PATH)
vw.plot_time_series_with_predicitons_bars(dataframe,
                                          labels,
                                          bars,
                                          pred_color='r')
