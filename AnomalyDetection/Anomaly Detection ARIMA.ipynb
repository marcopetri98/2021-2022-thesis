# %% [markdown]
# # Imports and constants

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

from Metrics import compute_metrics, make_metric_plots
import visualizer.Viewer as vw
from models.time_series.anomaly.statistical.TimeSeriesAnomalyARIMA import TimeSeriesAnomalyARIMA
from reader.NABTimeSeriesReader import NABTimeSeriesReader

# DATASET 1: ambient_temperature_system_failure
# DATASET 2: nyc_taxi
DATASET_PATH = "data/dataset/"
DATASET = "nyc_taxi.csv"
PURE_DATA_KEY = "realKnownCause/nyc_taxi.csv"
GROUND_WINDOWS_PATH = "data/dataset/combined_windows.json"
CHECK_OVERFITTING = False
ALL_DATA = False

def preprocess(X) -> np.ndarray:
    return StandardScaler().fit_transform(X)

# %% [markdown]
# # Read the dataset and train-test split

# %%
reader = NABTimeSeriesReader(DATASET_PATH)
all_df = reader.read(DATASET_PATH + DATASET).get_dataframe()
training, test = reader.train_test_split(train_perc=0.37).get_train_test_dataframes()

# Data used to train
data = preprocess(np.array(training["value"]).reshape((training["value"].shape[0], 1)))
data_labels = training["target"]

# Data used to test
data_test = preprocess(np.array(test["value"]).reshape((test["value"].shape[0], 1)))
data_test_labels = test["target"]

# Dataframe used to evaluate
dataframe = test.copy()
dataframe["value"] = data_test

train = data

if CHECK_OVERFITTING:
    data_test = data
    data_test_labels = data_labels
    dataframe = training.copy()
    dataframe["value"] = data_test
elif ALL_DATA:
    data_test = preprocess(np.array(all_df["value"]).reshape(all_df["value"].shape[0], 1))
    data_test_labels = all_df["target"]
    dataframe = all_df.copy()
    dataframe["value"] = data_test

# %% [markdown]
# # Create model, classify and score

# %%
model = TimeSeriesAnomalyARIMA(endog=train, order=(1, 1, 2), perc_quantile=0.98)
model.fit(fit_params={"method":"statespace",
                      "gls":True})

true_labels = data_test_labels

labels = model.classify(data_test.reshape((-1, 1)), data.reshape((-1, 1)))
scores = model.anomaly_score(data_test.reshape((-1, 1)), data.reshape((-1, 1)))
# Out:
# ==========================
# = Start of the model fit =
# ==========================
# [2022/05/17 10:25:21] Execution: Start to learn the parameters
# [2022/05/17 10:25:21] Execution: Parameters have been learnt
# [2022/05/17 10:25:21] Execution: Start to compute predictions of the test set
# [2022/05/17 10:25:21] Execution: Test set has been predicted
# [2022/05/17 10:25:21] Execution: Start to compute prediction errors
# [2022/05/17 10:25:21] Execution: Prediction errors have been computed
# [2022/05/17 10:25:21] Execution: Start to compute the threshold on the validation data
# [2022/05/17 10:25:21] Execution: Threshold has been computed
# [2022/05/17 10:25:21] Execution: The model has been trained and the results are:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3438
# Model:                 ARIMA(1, 1, 2)   Log Likelihood                 986.815
# Date:                Tue, 17 May 2022   AIC                          -1965.630
# Time:                        10:25:21   BIC                          -1941.064
# Sample:                             0   HQIC                         -1956.854
#                                - 3438
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.5896      0.028     21.330      0.000       0.535       0.644
# ma.L1         -0.0019      0.028     -0.070      0.944      -0.056       0.053
# ma.L2          0.1936      0.019     10.332      0.000       0.157       0.230
# sigma2         0.0330      0.000     69.748      0.000       0.032       0.034
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):              5223.49
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.60   Skew:                             0.05
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.04
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2022/05/17 10:25:21] Execution: The learnt threshold is 0.4011086682467031
# ========================
# = End of the model fit =
# ========================
# ============================
# = Start to classify points =
# ============================
# [2022/05/17 10:25:21] Execution: Start to compute predictions of the test set
# [2022/05/17 10:25:21] Execution: Test set has been predicted
# [2022/05/17 10:25:21] Execution: Start to compute prediction errors
# [2022/05/17 10:25:21] Execution: Prediction errors have been computed
# [2022/05/17 10:25:21] Execution: Evaluate point on their prediction error
# ================================
# = Points' classification ended =
# ================================
# ============================================
# = Start to compute anomaly score of points =
# ============================================
# [2022/05/17 10:25:21] Execution: Start to compute predictions of the test set
# [2022/05/17 10:25:21] Execution: Test set has been predicted
# [2022/05/17 10:25:21] Execution: Evaluate scores on the basis of prediction error
# =============================================
# = Anomaly score of points computation ended =
# =============================================

# %% [markdown]
# # Evaluation metrics for anomaly detection

# %%
compute_metrics(true_labels, scores, labels, only_roc_auc=False)
# Out:
# ACCURACY SCORE:  0.9638517151207506
# PRECISION SCORE:  0.004310344827586207
# RECALL SCORE:  0.2
# F1 SCORE:  0.008438818565400843
# AVERAGE PRECISION SCORE:  0.02917711457972533
# PRECISION-RECALL AUC SCORE:  0.014794780438409197
# AUROC SCORE:  0.42638546798029553

# %% [markdown]
# # Confusion matrix

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, labels)
vw.plot_confusion_matrix(confusion_matrix)

# %% [markdown]
# # ROC curve

# %%
vw.plot_roc_curve(true_labels, scores)

# %% [markdown]
# # Precision-recall curve

# %%
vw.plot_precision_recall_curve(true_labels, scores)

# %% [markdown]
# # Assigned labels

# %%
vw.plot_univariate_time_series_predictions(dataframe, labels)

# %% [markdown]
# # Assigned scores

# %%
vw.plot_univariate_time_series_predictions(dataframe, scores)

# %% [markdown]
# # Anomalies predictions as red dots

# %%
bars = vw.get_bars_indices_on_test_df(all_df,
                                      dataframe,
                                      PURE_DATA_KEY,
                                      GROUND_WINDOWS_PATH)
vw.plot_time_series_with_predicitons_bars(dataframe,
                                          labels,
                                          bars,
                                          pred_color='r')
