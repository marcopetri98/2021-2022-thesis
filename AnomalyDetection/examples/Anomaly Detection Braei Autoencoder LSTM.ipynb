# %% [markdown]
# # Imports and constants

# %%
import os

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

import visualizer.Viewer as vw
from Metrics import compute_metrics, make_metric_plots
from models.time_series.anomaly.deep_learning.LSTMAutoencoder import LSTMAutoencoder
from reader.NABTimeSeriesReader import NABTimeSeriesReader

# DATASET 1: ambient_temperature_system_failure
# DATASET 2: nyc_taxi
VALIDATION_DIM = 0.19
DATASET_PATH = "data/dataset/"
DATASET = "nyc_taxi.csv"
PURE_DATA_KEY = "realKnownCause/nyc_taxi.csv"
GROUND_WINDOWS_PATH = "data/dataset/combined_windows.json"
# The number of normal samples that must lie between a normal slice and an anomaly
SAFETY_DIM = 50
MINIMUM_SLICE = 100
ALL_METRICS = True
LOAD_MODEL = False
CHECK_OVERFITTING = False
AUTOENCODER_WINDOW = 32


def preprocess(X) -> np.ndarray:
    return StandardScaler().fit_transform(X)

# %% [markdown]
# # Set seed for reproducibility

# %%
np.random.seed(57)
tf.random.set_seed(57)

# %% [markdown]
# # Load training and testing data

# %%
reader = NABTimeSeriesReader(DATASET_PATH)
all_df = reader.read(DATASET_PATH + DATASET).get_dataframe()
training, test = reader.train_test_split(train_perc=0.37).get_train_test_dataframes()

# Data used to train
data = preprocess(np.array(training["value"]).reshape((training["value"].shape[0], 1)))
data_labels = training["target"]

# Data used to test
data_test = preprocess(np.array(test["value"]).reshape((test["value"].shape[0], 1)))
data_test_labels = test["target"]

# Eliminate exceeding points
if data_test.shape[0] % AUTOENCODER_WINDOW != 0:
    remainder_points = data_test.shape[0] % AUTOENCODER_WINDOW
    
    np_data = np.array(data)
    np_data_test = np.array(data_test)
    np_data_labels = np.array(data_labels)
    np_data_test_labels = np.array(data_test_labels)
    data = np.concatenate((np_data, np_data_test[0:remainder_points]))
    data_labels = np.concatenate((np_data_labels, np_data_test_labels[0:remainder_points]))
    data_test = data_test[remainder_points:]
    data_test_labels = data_test_labels[remainder_points:]
    
    np_train = np.concatenate((np.array(training), np.array(test[:remainder_points])))
    training = pd.DataFrame(np_train, columns=training.columns)
    
    np_test = np.array(test[remainder_points:])
    test = pd.DataFrame(np_test, columns=test.columns)

# Data used to evaluate
dataframe = test.copy()
dataframe["value"] = data_test

if CHECK_OVERFITTING:
    data_test = preprocess(np.array(training["value"]).reshape(training["value"].shape[0], 1))
    data_test_labels = training["target"]
    dataframe = training.copy()
    dataframe["value"] = data_test

# %% [markdown]
# # Set slices on which to train and validate
#
# In each case we use a self-supervised approach. The models are built to be able to correctly reproduce normal samples of the data. Therefore, from the training dataset, we want to exclude all possible anomalies and their neighbouring points not to learn anomalies patterns. In such a way, we aim the model to produce big mispredictions for those points that are anomalies. Given these statements, from training and validation set we extract slices without anomalies.

# %%
# Create the slices of the trainig data
change_idx = np.where(np.array(data_labels[:-1]) != np.array(data_labels[1:]))
change_idx = np.array(change_idx) + 1
change_idx = change_idx.reshape(change_idx.shape[1])
change_idx = np.concatenate((np.array([0]), change_idx))
normal_slices = []
anomaly_slices = []
for i in range(len(change_idx)):
    start = change_idx[i]
    if i < len(change_idx) -1:
        stop = change_idx[i+1]
    else:
        stop = data.shape[0]
    
    if data_labels[change_idx[i]] == 1:
        anomaly_slices.append(slice(start, stop))
    else:
        normal_slices.append(slice(start, stop))

print("The slices before safety check: %s" % normal_slices)

for i in range(len(normal_slices)):
    start_first = False
    end_last = False
    if normal_slices[i].start == 0:
        start_first = True
    if normal_slices[i].stop == data.shape[0]:
        end_last = True
    
    if not start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)
    elif not start_first and end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop,
                                 normal_slices[i].step)
    elif start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)

print("The slices after safety check: %s" % normal_slices)
# Out:
# The slices before safety check: [slice(0, 3824, None)]
# The slices after safety check: [slice(0, 3824, None)]

# %% [markdown]
# # Computation of training and validation slices
#
# Given the slices of normal points on which we will train and validate the model, we need to compute the slices characterizing the training and the validation samples of the dataset. To do so, we will need to iterate over the normal slices to compute the number of points in it. Then, we compute the number of points required for the validation set and from this number we will compute the validation slices. However, we risk to compute slices of only 1 sample in some extreme cases. Therefore, we will control that each slice is at least of `MINIMUM_SLICE` samples.

# %%
# Gets the step (equal for all slices)
step = normal_slices[0].step if normal_slices[0].step is not None else 1
ok_normal_slices = []
tot_samples = 0
for i in range(len(normal_slices)):
    samples = int((normal_slices[i].stop - normal_slices[i].start) / step)
    if samples > MINIMUM_SLICE:
        tot_samples += samples
        ok_normal_slices.append(normal_slices[i])
        
valid_points = tot_samples * VALIDATION_DIM
training_slices = []
validation_slices = []
tot_valid = 0
for i in reversed(range(len(ok_normal_slices))):
    if tot_valid >= valid_points:
        training_slices.append(ok_normal_slices[i])
    else:
        samples = int((ok_normal_slices[i].stop - ok_normal_slices[i].start) / step)
        needed_points = valid_points - tot_valid

        if samples < needed_points:
            validation_slices.append(ok_normal_slices[i])
        else:
            train_stop = int(ok_normal_slices[i].stop - needed_points * step)
            slice_train = slice(ok_normal_slices[i].start,
                                train_stop,
                                ok_normal_slices[i].step)
            slice_valid = slice(train_stop,
                                ok_normal_slices[i].stop,
                                ok_normal_slices[i].step)
            
            # If points are enough, they are added to lists
            if (slice_train.stop - slice_train.start) / step >= MINIMUM_SLICE:
                training_slices.append(slice_train)
            if (slice_valid.stop - slice_valid.start) / step >= MINIMUM_SLICE:
                validation_slices.append(slice_valid)
                
            # Since in this else we enter only at the last slice, set up to exit in case minimum
            # slice is not reached
            tot_valid = valid_points + 1
            
training_slices.reverse()
validation_slices.reverse()

print("The training slices are: %s" % training_slices)
print("The validation slices are: %s" % validation_slices)
# Out:
# The training slices are: [slice(0, 3097, None)]
# The validation slices are: [slice(3097, 3824, None)]

# %% [markdown]
# # Load or fit the model

# %%
model = LSTMAutoencoder(window=AUTOENCODER_WINDOW,
                        max_epochs=500,
                        batch_size=32,
                        folder_save_path="data/nn_models/custom/",
                        distribution="gaussian",
                        extend_not_multiple=True,
                        test_overlapping=True,
                        filename="nyc_ae_lstm")
if LOAD_MODEL:
    model.load_model("data/nn_models/nyc_ae_lstm")
else:
    model.fit(data, training_slices, validation_slices, data_labels)
# Out:
# [2022/05/17 18:19:30] WARNING: Data will be modified to match the window size, note that the input must be a multiple of the window size for autoencoders. This is just a comfort utility. You can ignore this warning if no other warnings regarding the training set pop up.
# [2022/05/17 18:19:30] WARNING: On 1th training slice, 25 points have been lost
# [2022/05/17 18:19:30] WARNING: On 1th validation slice, 23 points have been lost
# Model: "lstm_autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 32, 1)]           0
#
#  encoder_lstm_1 (LSTM)       (None, 32, 32)            4352
#
#  encoder_lstm_2 (LSTM)       (None, 32, 8)             1312
#
#  encoder_lstm_3 (LSTM)       (None, 2)                 88
#
#  repeat_vector (RepeatVector  (None, 32, 2)            0
#  )
#
#  decoder_lstm_1 (LSTM)       (None, 32, 2)             40
#
#  decoder_lstm_2 (LSTM)       (None, 32, 8)             352
#
#  decoder_lstm_3 (LSTM)       (None, 32, 32)            5248
#
#  time_distributed (TimeDistr  (None, 32, 1)            33
#  ibuted)
#
# =================================================================
# Total params: 11,425
# Trainable params: 11,425
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 76/76 [==============================] - 17s 85ms/step - loss: 0.8461 - mean_squared_error: 0.8461 - val_loss: 0.6520 - val_mean_squared_error: 0.6520 - lr: 0.0010
# Epoch 2/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.6419 - mean_squared_error: 0.6419 - val_loss: 0.3423 - val_mean_squared_error: 0.3423 - lr: 0.0010
# Epoch 3/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.3237 - mean_squared_error: 0.3237 - val_loss: 0.2389 - val_mean_squared_error: 0.2389 - lr: 0.0010
# Epoch 4/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.2566 - mean_squared_error: 0.2566 - val_loss: 0.2022 - val_mean_squared_error: 0.2022 - lr: 0.0010
# Epoch 5/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.2243 - mean_squared_error: 0.2243 - val_loss: 0.1874 - val_mean_squared_error: 0.1874 - lr: 0.0010
# Epoch 6/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.2081 - mean_squared_error: 0.2081 - val_loss: 0.1675 - val_mean_squared_error: 0.1675 - lr: 0.0010
# Epoch 7/500
# 76/76 [==============================] - 5s 67ms/step - loss: 0.1944 - mean_squared_error: 0.1944 - val_loss: 0.1587 - val_mean_squared_error: 0.1587 - lr: 0.0010
# Epoch 8/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.1849 - mean_squared_error: 0.1849 - val_loss: 0.1486 - val_mean_squared_error: 0.1486 - lr: 0.0010
# Epoch 9/500
# 76/76 [==============================] - 4s 49ms/step - loss: 0.1762 - mean_squared_error: 0.1762 - val_loss: 0.1427 - val_mean_squared_error: 0.1427 - lr: 0.0010
# Epoch 10/500
# 76/76 [==============================] - 4s 50ms/step - loss: 0.1658 - mean_squared_error: 0.1658 - val_loss: 0.1359 - val_mean_squared_error: 0.1359 - lr: 0.0010
# Epoch 11/500
# 76/76 [==============================] - 4s 48ms/step - loss: 0.1600 - mean_squared_error: 0.1600 - val_loss: 0.1317 - val_mean_squared_error: 0.1317 - lr: 0.0010
# Epoch 12/500
# 76/76 [==============================] - 4s 56ms/step - loss: 0.1436 - mean_squared_error: 0.1436 - val_loss: 0.1108 - val_mean_squared_error: 0.1108 - lr: 0.0010
# Epoch 13/500
# 76/76 [==============================] - 4s 49ms/step - loss: 0.1365 - mean_squared_error: 0.1365 - val_loss: 0.1106 - val_mean_squared_error: 0.1106 - lr: 0.0010
# Epoch 14/500
# 76/76 [==============================] - 5s 60ms/step - loss: 0.1287 - mean_squared_error: 0.1287 - val_loss: 0.1048 - val_mean_squared_error: 0.1048 - lr: 0.0010
# Epoch 15/500
# 76/76 [==============================] - 5s 62ms/step - loss: 0.1330 - mean_squared_error: 0.1330 - val_loss: 0.1047 - val_mean_squared_error: 0.1047 - lr: 0.0010
# Epoch 16/500
# 76/76 [==============================] - 4s 54ms/step - loss: 0.1179 - mean_squared_error: 0.1179 - val_loss: 0.1025 - val_mean_squared_error: 0.1025 - lr: 0.0010
# Epoch 17/500
# 76/76 [==============================] - 4s 48ms/step - loss: 0.1140 - mean_squared_error: 0.1140 - val_loss: 0.0919 - val_mean_squared_error: 0.0919 - lr: 0.0010
# Epoch 18/500
# 76/76 [==============================] - 4s 57ms/step - loss: 0.1162 - mean_squared_error: 0.1162 - val_loss: 0.1077 - val_mean_squared_error: 0.1077 - lr: 0.0010
# Epoch 19/500
# 76/76 [==============================] - 4s 47ms/step - loss: 0.1238 - mean_squared_error: 0.1238 - val_loss: 0.1065 - val_mean_squared_error: 0.1065 - lr: 0.0010
# Epoch 20/500
# 76/76 [==============================] - 4s 46ms/step - loss: 0.1116 - mean_squared_error: 0.1116 - val_loss: 0.0857 - val_mean_squared_error: 0.0857 - lr: 0.0010
# Epoch 21/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.1022 - mean_squared_error: 0.1022 - val_loss: 0.0833 - val_mean_squared_error: 0.0833 - lr: 0.0010
# Epoch 22/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0985 - mean_squared_error: 0.0985 - val_loss: 0.0807 - val_mean_squared_error: 0.0807 - lr: 0.0010
# Epoch 23/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0967 - mean_squared_error: 0.0967 - val_loss: 0.0795 - val_mean_squared_error: 0.0795 - lr: 0.0010
# Epoch 24/500
# 76/76 [==============================] - 3s 45ms/step - loss: 0.0947 - mean_squared_error: 0.0947 - val_loss: 0.0739 - val_mean_squared_error: 0.0739 - lr: 0.0010
# Epoch 25/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0915 - mean_squared_error: 0.0915 - val_loss: 0.0774 - val_mean_squared_error: 0.0774 - lr: 0.0010
# Epoch 26/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0903 - mean_squared_error: 0.0903 - val_loss: 0.0734 - val_mean_squared_error: 0.0734 - lr: 0.0010
# Epoch 27/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0888 - mean_squared_error: 0.0888 - val_loss: 0.0746 - val_mean_squared_error: 0.0746 - lr: 0.0010
# Epoch 28/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0873 - mean_squared_error: 0.0873 - val_loss: 0.0708 - val_mean_squared_error: 0.0708 - lr: 0.0010
# Epoch 29/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0867 - mean_squared_error: 0.0867 - val_loss: 0.0712 - val_mean_squared_error: 0.0712 - lr: 0.0010
# Epoch 30/500
# 76/76 [==============================] - 4s 58ms/step - loss: 0.0845 - mean_squared_error: 0.0845 - val_loss: 0.0695 - val_mean_squared_error: 0.0695 - lr: 0.0010
# Epoch 31/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0827 - mean_squared_error: 0.0827 - val_loss: 0.0722 - val_mean_squared_error: 0.0722 - lr: 0.0010
# Epoch 32/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0867 - mean_squared_error: 0.0867 - val_loss: 0.0747 - val_mean_squared_error: 0.0747 - lr: 0.0010
# Epoch 33/500
# 76/76 [==============================] - 3s 39ms/step - loss: 0.0861 - mean_squared_error: 0.0861 - val_loss: 0.0698 - val_mean_squared_error: 0.0698 - lr: 0.0010
# Epoch 34/500
# 76/76 [==============================] - 4s 48ms/step - loss: 0.0806 - mean_squared_error: 0.0806 - val_loss: 0.0673 - val_mean_squared_error: 0.0673 - lr: 0.0010
# Epoch 35/500
# 76/76 [==============================] - 4s 47ms/step - loss: 0.0817 - mean_squared_error: 0.0817 - val_loss: 0.0691 - val_mean_squared_error: 0.0691 - lr: 0.0010
# Epoch 36/500
# 76/76 [==============================] - 4s 47ms/step - loss: 0.0787 - mean_squared_error: 0.0787 - val_loss: 0.0643 - val_mean_squared_error: 0.0643 - lr: 0.0010
# Epoch 37/500
# 76/76 [==============================] - 5s 63ms/step - loss: 0.0793 - mean_squared_error: 0.0793 - val_loss: 0.0664 - val_mean_squared_error: 0.0664 - lr: 0.0010
# Epoch 38/500
# 76/76 [==============================] - 4s 51ms/step - loss: 0.0774 - mean_squared_error: 0.0774 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - lr: 0.0010
# Epoch 39/500
# 76/76 [==============================] - 4s 51ms/step - loss: 0.0775 - mean_squared_error: 0.0775 - val_loss: 0.0633 - val_mean_squared_error: 0.0633 - lr: 0.0010
# Epoch 40/500
# 76/76 [==============================] - 5s 64ms/step - loss: 0.0749 - mean_squared_error: 0.0749 - val_loss: 0.0615 - val_mean_squared_error: 0.0615 - lr: 0.0010
# Epoch 41/500
# 76/76 [==============================] - 4s 48ms/step - loss: 0.0740 - mean_squared_error: 0.0740 - val_loss: 0.0639 - val_mean_squared_error: 0.0639 - lr: 0.0010
# Epoch 42/500
# 76/76 [==============================] - 4s 59ms/step - loss: 0.0736 - mean_squared_error: 0.0736 - val_loss: 0.0637 - val_mean_squared_error: 0.0637 - lr: 0.0010
# Epoch 43/500
# 76/76 [==============================] - 4s 47ms/step - loss: 0.0725 - mean_squared_error: 0.0725 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - lr: 0.0010
# Epoch 44/500
# 76/76 [==============================] - 3s 44ms/step - loss: 0.0715 - mean_squared_error: 0.0715 - val_loss: 0.0614 - val_mean_squared_error: 0.0614 - lr: 0.0010
# Epoch 45/500
# 76/76 [==============================] - 3s 45ms/step - loss: 0.0716 - mean_squared_error: 0.0716 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - lr: 0.0010
# Epoch 46/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0708 - mean_squared_error: 0.0708 - val_loss: 0.0602 - val_mean_squared_error: 0.0602 - lr: 0.0010
# Epoch 47/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0691 - mean_squared_error: 0.0691 - val_loss: 0.0619 - val_mean_squared_error: 0.0619 - lr: 0.0010
# Epoch 48/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0680 - mean_squared_error: 0.0680 - val_loss: 0.0603 - val_mean_squared_error: 0.0603 - lr: 0.0010
# Epoch 49/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0685 - mean_squared_error: 0.0685 - val_loss: 0.0645 - val_mean_squared_error: 0.0645 - lr: 0.0010
# Epoch 50/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0714 - mean_squared_error: 0.0714 - val_loss: 0.0579 - val_mean_squared_error: 0.0579 - lr: 0.0010
# Epoch 51/500
# 76/76 [==============================] - 3s 44ms/step - loss: 0.0666 - mean_squared_error: 0.0666 - val_loss: 0.0607 - val_mean_squared_error: 0.0607 - lr: 0.0010
# Epoch 52/500
# 76/76 [==============================] - 4s 47ms/step - loss: 0.0663 - mean_squared_error: 0.0663 - val_loss: 0.0568 - val_mean_squared_error: 0.0568 - lr: 0.0010
# Epoch 53/500
# 76/76 [==============================] - 3s 44ms/step - loss: 0.0654 - mean_squared_error: 0.0654 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - lr: 0.0010
# Epoch 54/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0669 - mean_squared_error: 0.0669 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - lr: 0.0010
# Epoch 55/500
# 76/76 [==============================] - 3s 46ms/step - loss: 0.0716 - mean_squared_error: 0.0716 - val_loss: 0.0698 - val_mean_squared_error: 0.0698 - lr: 0.0010
# Epoch 56/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0685 - mean_squared_error: 0.0685 - val_loss: 0.0592 - val_mean_squared_error: 0.0592 - lr: 0.0010
# Epoch 57/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0626 - mean_squared_error: 0.0626 - val_loss: 0.0619 - val_mean_squared_error: 0.0619 - lr: 0.0010
# Epoch 58/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0613 - mean_squared_error: 0.0613 - val_loss: 0.0569 - val_mean_squared_error: 0.0569 - lr: 0.0010
# Epoch 59/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0615 - mean_squared_error: 0.0615 - val_loss: 0.0565 - val_mean_squared_error: 0.0565 - lr: 0.0010
# Epoch 60/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0595 - mean_squared_error: 0.0595 - val_loss: 0.0582 - val_mean_squared_error: 0.0582 - lr: 0.0010
# Epoch 61/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0586 - mean_squared_error: 0.0586 - val_loss: 0.0578 - val_mean_squared_error: 0.0578 - lr: 0.0010
# Epoch 62/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0596 - mean_squared_error: 0.0596 - val_loss: 0.0610 - val_mean_squared_error: 0.0610 - lr: 0.0010
# Epoch 63/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0613 - mean_squared_error: 0.0613 - val_loss: 0.0588 - val_mean_squared_error: 0.0588 - lr: 0.0010
# Epoch 64/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0596 - mean_squared_error: 0.0596 - val_loss: 0.0573 - val_mean_squared_error: 0.0573 - lr: 0.0010
# Epoch 65/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0586 - mean_squared_error: 0.0586 - val_loss: 0.0560 - val_mean_squared_error: 0.0560 - lr: 0.0010
# Epoch 66/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0586 - mean_squared_error: 0.0586 - val_loss: 0.0582 - val_mean_squared_error: 0.0582 - lr: 0.0010
# Epoch 67/500
# 76/76 [==============================] - 3s 45ms/step - loss: 0.0562 - mean_squared_error: 0.0562 - val_loss: 0.0613 - val_mean_squared_error: 0.0613 - lr: 0.0010
# Epoch 68/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0566 - mean_squared_error: 0.0566 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - lr: 0.0010
# Epoch 69/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0588 - mean_squared_error: 0.0588 - val_loss: 0.0612 - val_mean_squared_error: 0.0612 - lr: 0.0010
# Epoch 70/500
# 76/76 [==============================] - 3s 40ms/step - loss: 0.0577 - mean_squared_error: 0.0577 - val_loss: 0.0704 - val_mean_squared_error: 0.0704 - lr: 0.0010
# Epoch 71/500
# 76/76 [==============================] - 3s 38ms/step - loss: 0.0556 - mean_squared_error: 0.0556 - val_loss: 0.0583 - val_mean_squared_error: 0.0583 - lr: 0.0010
# Epoch 72/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0549 - mean_squared_error: 0.0549 - val_loss: 0.0618 - val_mean_squared_error: 0.0618 - lr: 0.0010
# Epoch 73/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0551 - mean_squared_error: 0.0551 - val_loss: 0.0618 - val_mean_squared_error: 0.0618 - lr: 0.0010
# Epoch 74/500
# 76/76 [==============================] - 3s 40ms/step - loss: 0.0541 - mean_squared_error: 0.0541 - val_loss: 0.0575 - val_mean_squared_error: 0.0575 - lr: 0.0010
# Epoch 75/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0565 - mean_squared_error: 0.0565 - val_loss: 0.0561 - val_mean_squared_error: 0.0561 - lr: 0.0010
# Epoch 76/500
# 76/76 [==============================] - 3s 44ms/step - loss: 0.0543 - mean_squared_error: 0.0543 - val_loss: 0.0597 - val_mean_squared_error: 0.0597 - lr: 0.0010
# Epoch 77/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0546 - mean_squared_error: 0.0546 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - lr: 0.0010
# Epoch 78/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0553 - mean_squared_error: 0.0553 - val_loss: 0.0591 - val_mean_squared_error: 0.0591 - lr: 0.0010
# Epoch 79/500
# 76/76 [==============================] - 3s 45ms/step - loss: 0.0550 - mean_squared_error: 0.0550 - val_loss: 0.0596 - val_mean_squared_error: 0.0596 - lr: 0.0010
# Epoch 80/500
# 76/76 [==============================] - 5s 66ms/step - loss: 0.0527 - mean_squared_error: 0.0527 - val_loss: 0.0560 - val_mean_squared_error: 0.0560 - lr: 0.0010
# Epoch 81/500
# 76/76 [==============================] - 4s 53ms/step - loss: 0.0531 - mean_squared_error: 0.0531 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - lr: 0.0010
# Epoch 82/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0532 - mean_squared_error: 0.0532 - val_loss: 0.0565 - val_mean_squared_error: 0.0565 - lr: 0.0010
# Epoch 83/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0517 - mean_squared_error: 0.0517 - val_loss: 0.0545 - val_mean_squared_error: 0.0545 - lr: 0.0010
# Epoch 84/500
# 76/76 [==============================] - 4s 51ms/step - loss: 0.0518 - mean_squared_error: 0.0518 - val_loss: 0.0604 - val_mean_squared_error: 0.0604 - lr: 0.0010
# Epoch 85/500
# 76/76 [==============================] - 3s 44ms/step - loss: 0.0525 - mean_squared_error: 0.0525 - val_loss: 0.0548 - val_mean_squared_error: 0.0548 - lr: 0.0010
# Epoch 86/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0507 - mean_squared_error: 0.0507 - val_loss: 0.0535 - val_mean_squared_error: 0.0535 - lr: 0.0010
# Epoch 87/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0501 - mean_squared_error: 0.0501 - val_loss: 0.0553 - val_mean_squared_error: 0.0553 - lr: 0.0010
# Epoch 88/500
# 76/76 [==============================] - 4s 47ms/step - loss: 0.0495 - mean_squared_error: 0.0495 - val_loss: 0.0561 - val_mean_squared_error: 0.0561 - lr: 0.0010
# Epoch 89/500
# 76/76 [==============================] - 3s 40ms/step - loss: 0.0517 - mean_squared_error: 0.0517 - val_loss: 0.0553 - val_mean_squared_error: 0.0553 - lr: 0.0010
# Epoch 90/500
# 76/76 [==============================] - 3s 40ms/step - loss: 0.0496 - mean_squared_error: 0.0496 - val_loss: 0.0557 - val_mean_squared_error: 0.0557 - lr: 0.0010
# Epoch 91/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0498 - mean_squared_error: 0.0498 - val_loss: 0.0556 - val_mean_squared_error: 0.0556 - lr: 0.0010
# Epoch 92/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0491 - mean_squared_error: 0.0491 - val_loss: 0.0546 - val_mean_squared_error: 0.0546 - lr: 0.0010
# Epoch 93/500
# 76/76 [==============================] - 3s 42ms/step - loss: 0.0494 - mean_squared_error: 0.0494 - val_loss: 0.0549 - val_mean_squared_error: 0.0549 - lr: 0.0010
# Epoch 94/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0484 - mean_squared_error: 0.0484 - val_loss: 0.0567 - val_mean_squared_error: 0.0567 - lr: 0.0010
# Epoch 95/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0482 - mean_squared_error: 0.0482 - val_loss: 0.0578 - val_mean_squared_error: 0.0578 - lr: 0.0010
# Epoch 96/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0481 - mean_squared_error: 0.0481 - val_loss: 0.0574 - val_mean_squared_error: 0.0574 - lr: 0.0010
# Epoch 97/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0479 - mean_squared_error: 0.0479 - val_loss: 0.0568 - val_mean_squared_error: 0.0568 - lr: 0.0010
# Epoch 98/500
# 76/76 [==============================] - 3s 40ms/step - loss: 0.0509 - mean_squared_error: 0.0509 - val_loss: 0.0589 - val_mean_squared_error: 0.0589 - lr: 0.0010
# Epoch 99/500
# 76/76 [==============================] - 3s 40ms/step - loss: 0.0500 - mean_squared_error: 0.0500 - val_loss: 0.0586 - val_mean_squared_error: 0.0586 - lr: 0.0010
# Epoch 100/500
# 76/76 [==============================] - 3s 45ms/step - loss: 0.0499 - mean_squared_error: 0.0499 - val_loss: 0.0644 - val_mean_squared_error: 0.0644 - lr: 0.0010
# Epoch 101/500
# 76/76 [==============================] - 3s 40ms/step - loss: 0.0908 - mean_squared_error: 0.0908 - val_loss: 0.1537 - val_mean_squared_error: 0.1537 - lr: 0.0010
# Epoch 102/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.1398 - mean_squared_error: 0.1398 - val_loss: 0.1180 - val_mean_squared_error: 0.1180 - lr: 0.0010
# Epoch 103/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0963 - mean_squared_error: 0.0963 - val_loss: 0.0786 - val_mean_squared_error: 0.0786 - lr: 0.0010
# Epoch 104/500
# 76/76 [==============================] - 3s 44ms/step - loss: 0.0738 - mean_squared_error: 0.0738 - val_loss: 0.0692 - val_mean_squared_error: 0.0692 - lr: 0.0010
# Epoch 105/500
# 76/76 [==============================] - 3s 46ms/step - loss: 0.0648 - mean_squared_error: 0.0648 - val_loss: 0.0646 - val_mean_squared_error: 0.0646 - lr: 0.0010
# Epoch 106/500
# 76/76 [==============================] - 3s 44ms/step - loss: 0.0632 - mean_squared_error: 0.0632 - val_loss: 0.0672 - val_mean_squared_error: 0.0672 - lr: 0.0010
# Epoch 107/500
# 76/76 [==============================] - 4s 47ms/step - loss: 0.0588 - mean_squared_error: 0.0588 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - lr: 1.0000e-04
# Epoch 108/500
# 76/76 [==============================] - 4s 47ms/step - loss: 0.0582 - mean_squared_error: 0.0582 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - lr: 1.0000e-04
# Epoch 109/500
# 76/76 [==============================] - 4s 55ms/step - loss: 0.0577 - mean_squared_error: 0.0577 - val_loss: 0.0622 - val_mean_squared_error: 0.0622 - lr: 1.0000e-04
# Epoch 110/500
# 76/76 [==============================] - 4s 48ms/step - loss: 0.0574 - mean_squared_error: 0.0574 - val_loss: 0.0626 - val_mean_squared_error: 0.0626 - lr: 1.0000e-04
# Epoch 111/500
# 76/76 [==============================] - 4s 49ms/step - loss: 0.0572 - mean_squared_error: 0.0572 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - lr: 1.0000e-04
# Epoch 112/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0569 - mean_squared_error: 0.0569 - val_loss: 0.0629 - val_mean_squared_error: 0.0629 - lr: 1.0000e-04
# Epoch 113/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0567 - mean_squared_error: 0.0567 - val_loss: 0.0625 - val_mean_squared_error: 0.0625 - lr: 1.0000e-04
# Epoch 114/500
# 76/76 [==============================] - 3s 43ms/step - loss: 0.0565 - mean_squared_error: 0.0565 - val_loss: 0.0630 - val_mean_squared_error: 0.0630 - lr: 1.0000e-04
# Epoch 115/500
# 76/76 [==============================] - 3s 41ms/step - loss: 0.0563 - mean_squared_error: 0.0563 - val_loss: 0.0631 - val_mean_squared_error: 0.0631 - lr: 1.0000e-04
# Epoch 116/500
# 76/76 [==============================] - 3s 40ms/step - loss: 0.0561 - mean_squared_error: 0.0561 - val_loss: 0.0630 - val_mean_squared_error: 0.0630 - lr: 1.0000e-04

# %% [markdown]
# # Compute labels and scores

# %%
true_labels = np.asarray(data_test_labels, dtype=np.intc)
labels = model.predict(data, data_test)
scores = model.anomaly_score(data, data_test)
perc = np.sum(labels) / labels.shape[0]

# %% [markdown]
# # Evaluation metrics for anomaly detection

# %%
compute_metrics(true_labels, scores, labels, compute_roc_auc=not CHECK_OVERFITTING, only_roc_auc=False)
# Out:
# ACCURACY SCORE:  0.9826046798029556
# PRECISION SCORE:  0.017857142857142856
# RECALL SCORE:  0.4
# F1 SCORE:  0.034188034188034185
# AVERAGE PRECISION SCORE:  0.017725955417910173
# PRECISION-RECALL AUC SCORE:  0.011600545078134737
# AUROC SCORE:  0.7434293637344015

# %% [markdown]
# # Confusion matrix

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, labels)
vw.plot_confusion_matrix(confusion_matrix)

# %% [markdown]
# # ROC curve

# %%
vw.plot_roc_curve(true_labels, scores)

# %% [markdown]
# # Precision-recall curve

# %%
vw.plot_precision_recall_curve(true_labels, scores)

# %% [markdown]
# # Assigned labels

# %%
vw.plot_univariate_time_series_predictions(dataframe, labels)

# %% [markdown]
# # Assigned scores

# %%
vw.plot_univariate_time_series_predictions(dataframe, scores)

# %% [markdown]
# # Data and predictions

# %%
predictions = model.predict_time_series(data[validation_slices[0]], data_test)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=True)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=False)

# %% [markdown]
# # Anomalies predictions as red dots

# %%
bars = vw.get_bars_indices_on_test_df(all_df,
                                      dataframe,
                                      PURE_DATA_KEY,
                                      GROUND_WINDOWS_PATH)
vw.plot_time_series_with_predicitons_bars(dataframe,
                                          labels,
                                          bars,
                                          pred_color='r')
