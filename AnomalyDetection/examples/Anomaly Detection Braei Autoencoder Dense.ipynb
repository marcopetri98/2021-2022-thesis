# %% [markdown]
# # Imports and constants

# %%
import os

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

import visualizer.Viewer as vw
from Metrics import compute_metrics, make_metric_plots
from models.time_series.anomaly.deep_learning.BraeiDenseAutoencoder import BraeiDenseAutoencoder
from reader.NABTimeSeriesReader import NABTimeSeriesReader

# DATASET 1: ambient_temperature_system_failure
# DATASET 2: nyc_taxi
VALIDATION_DIM = 0.19
DATASET_PATH = "data/dataset/"
DATASET = "nyc_taxi.csv"
PURE_DATA_KEY = "realKnownCause/nyc_taxi.csv"
GROUND_WINDOWS_PATH = "data/dataset/combined_windows.json"
# The number of normal samples that must lie between a normal slice and an anomaly
SAFETY_DIM = 50
MINIMUM_SLICE = 100
ALL_METRICS = True
LOAD_MODEL = False
CHECK_OVERFITTING = False
AUTOENCODER_WINDOW = 32


def preprocess(X) -> np.ndarray:
    return StandardScaler().fit_transform(X)

# %% [markdown]
# # Set seed for reproducibility

# %%
np.random.seed(57)
tf.random.set_seed(57)

# %% [markdown]
# # Load training and testing data

# %%
reader = NABTimeSeriesReader(DATASET_PATH)
all_df = reader.read(DATASET_PATH + DATASET).get_dataframe()
training, test = reader.train_test_split(train_perc=0.37).get_train_test_dataframes()

# Data used to train
data = preprocess(np.array(training["value"]).reshape((training["value"].shape[0], 1)))
data_labels = training["target"]

# Data used to test
data_test = preprocess(np.array(test["value"]).reshape((test["value"].shape[0], 1)))
data_test_labels = test["target"]

# Eliminate exceeding points
if data_test.shape[0] % AUTOENCODER_WINDOW != 0:
    remainder_points = data_test.shape[0] % AUTOENCODER_WINDOW
    
    np_data = np.array(data)
    np_data_test = np.array(data_test)
    np_data_labels = np.array(data_labels)
    np_data_test_labels = np.array(data_test_labels)
    data = np.concatenate((np_data, np_data_test[0:remainder_points]))
    data_labels = np.concatenate((np_data_labels, np_data_test_labels[0:remainder_points]))
    data_test = data_test[remainder_points:]
    data_test_labels = data_test_labels[remainder_points:]
    
    np_train = np.concatenate((np.array(training), np.array(test[:remainder_points])))
    training = pd.DataFrame(np_train, columns=training.columns)
    
    np_test = np.array(test[remainder_points:])
    test = pd.DataFrame(np_test, columns=test.columns)

# Data used to evaluate
dataframe = test.copy()
dataframe["value"] = data_test

if CHECK_OVERFITTING:
    data_test = preprocess(np.array(training["value"]).reshape(training["value"].shape[0], 1))
    data_test_labels = training["target"]
    dataframe = training.copy()
    dataframe["value"] = data_test

# %% [markdown]
# # Set slices on which to train and validate
#
# In each case we use a self-supervised approach. The models are built to be able to correctly reproduce normal samples of the data. Therefore, from the training dataset, we want to exclude all possible anomalies and their neighbouring points not to learn anomalies patterns. In such a way, we aim the model to produce big mispredictions for those points that are anomalies. Given these statements, from training and validation set we extract slices without anomalies.

# %%
# Create the slices of the trainig data
change_idx = np.where(np.array(data_labels[:-1]) != np.array(data_labels[1:]))
change_idx = np.array(change_idx) + 1
change_idx = change_idx.reshape(change_idx.shape[1])
change_idx = np.concatenate((np.array([0]), change_idx))
normal_slices = []
anomaly_slices = []
for i in range(len(change_idx)):
    start = change_idx[i]
    if i < len(change_idx) -1:
        stop = change_idx[i+1]
    else:
        stop = data.shape[0]
    
    if data_labels[change_idx[i]] == 1:
        anomaly_slices.append(slice(start, stop))
    else:
        normal_slices.append(slice(start, stop))

print("The slices before safety check: %s" % normal_slices)

for i in range(len(normal_slices)):
    start_first = False
    end_last = False
    if normal_slices[i].start == 0:
        start_first = True
    if normal_slices[i].stop == data.shape[0]:
        end_last = True
    
    if not start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)
    elif not start_first and end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop,
                                 normal_slices[i].step)
    elif start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)

print("The slices after safety check: %s" % normal_slices)
# Out:
# The slices before safety check: [slice(0, 3824, None)]
# The slices after safety check: [slice(0, 3824, None)]

# %% [markdown]
# # Computation of training and validation slices
#
# Given the slices of normal points on which we will train and validate the model, we need to compute the slices characterizing the training and the validation samples of the dataset. To do so, we will need to iterate over the normal slices to compute the number of points in it. Then, we compute the number of points required for the validation set and from this number we will compute the validation slices. However, we risk to compute slices of only 1 sample in some extreme cases. Therefore, we will control that each slice is at least of `MINIMUM_SLICE` samples.

# %%
# Gets the step (equal for all slices)
step = normal_slices[0].step if normal_slices[0].step is not None else 1
ok_normal_slices = []
tot_samples = 0
for i in range(len(normal_slices)):
    samples = int((normal_slices[i].stop - normal_slices[i].start) / step)
    if samples > MINIMUM_SLICE:
        tot_samples += samples
        ok_normal_slices.append(normal_slices[i])
        
valid_points = tot_samples * VALIDATION_DIM
training_slices = []
validation_slices = []
tot_valid = 0
for i in reversed(range(len(ok_normal_slices))):
    if tot_valid >= valid_points:
        training_slices.append(ok_normal_slices[i])
    else:
        samples = int((ok_normal_slices[i].stop - ok_normal_slices[i].start) / step)
        needed_points = valid_points - tot_valid

        if samples < needed_points:
            validation_slices.append(ok_normal_slices[i])
        else:
            train_stop = int(ok_normal_slices[i].stop - needed_points * step)
            slice_train = slice(ok_normal_slices[i].start,
                                train_stop,
                                ok_normal_slices[i].step)
            slice_valid = slice(train_stop,
                                ok_normal_slices[i].stop,
                                ok_normal_slices[i].step)
            
            # If points are enough, they are added to lists
            if (slice_train.stop - slice_train.start) / step >= MINIMUM_SLICE:
                training_slices.append(slice_train)
            if (slice_valid.stop - slice_valid.start) / step >= MINIMUM_SLICE:
                validation_slices.append(slice_valid)
                
            # Since in this else we enter only at the last slice, set up to exit in case minimum
            # slice is not reached
            tot_valid = valid_points + 1
            
training_slices.reverse()
validation_slices.reverse()

print("The training slices are: %s" % training_slices)
print("The validation slices are: %s" % validation_slices)
# Out:
# The training slices are: [slice(0, 3097, None)]
# The validation slices are: [slice(3097, 3824, None)]

# %% [markdown]
# # Load or fit the model

# %%
model = BraeiDenseAutoencoder(window=AUTOENCODER_WINDOW,
                              max_epochs=50,
                              batch_size=32,
                              predict_validation=0.1982,
                              distribution="gaussian",
                              perc_quantile=0.98,
                              filename="nyc_ae_braei_dense",
                              test_overlapping=False)
if LOAD_MODEL:
    model.load_model("data/nn_models/nyc_ae_braei_dense")
else:
    model.fit(data, training_slices, validation_slices, data_labels)
# Out:
# [2022/05/17 18:16:14] WARNING: Data will be modified to match the window size, note that the input must be a multiple of the window size for autoencoders. This is just a comfort utility. You can ignore this warning if no other warnings regarding the training set pop up.
# [2022/05/17 18:16:14] WARNING: On 1th training slice, 25 points have been lost
# [2022/05/17 18:16:14] WARNING: On 1th validation slice, 23 points have been lost
# Model: "dense_autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 32, 1)]           0
#
#  flatten (Flatten)           (None, 32)                0
#
#  encoder_dense_1 (Dense)     (None, 32)                1056
#
#  encoder_dense_2 (Dense)     (None, 16)                528
#
#  latent_layer (Dense)        (None, 8)                 136
#
#  decoder_dense_1 (Dense)     (None, 16)                144
#
#  decoder_dense_2 (Dense)     (None, 32)                544
#
#  output (Dense)              (None, 32)                1056
#
# =================================================================
# Total params: 3,464
# Trainable params: 3,464
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 77/77 [==============================] - 1s 6ms/step - loss: 0.8177 - mean_squared_error: 0.8177 - val_loss: 0.4697 - val_mean_squared_error: 0.4697 - lr: 0.0010
# Epoch 2/50
# 77/77 [==============================] - 0s 5ms/step - loss: 0.3044 - mean_squared_error: 0.3044 - val_loss: 0.1124 - val_mean_squared_error: 0.1124 - lr: 0.0010
# Epoch 3/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.1108 - mean_squared_error: 0.1108 - val_loss: 0.0681 - val_mean_squared_error: 0.0681 - lr: 0.0010
# Epoch 4/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0790 - mean_squared_error: 0.0790 - val_loss: 0.0566 - val_mean_squared_error: 0.0566 - lr: 0.0010
# Epoch 5/50
# 77/77 [==============================] - 0s 5ms/step - loss: 0.0682 - mean_squared_error: 0.0682 - val_loss: 0.0507 - val_mean_squared_error: 0.0507 - lr: 0.0010
# Epoch 6/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0617 - mean_squared_error: 0.0617 - val_loss: 0.0446 - val_mean_squared_error: 0.0446 - lr: 0.0010
# Epoch 7/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0565 - mean_squared_error: 0.0565 - val_loss: 0.0413 - val_mean_squared_error: 0.0413 - lr: 0.0010
# Epoch 8/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0528 - mean_squared_error: 0.0528 - val_loss: 0.0397 - val_mean_squared_error: 0.0397 - lr: 0.0010
# Epoch 9/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0498 - mean_squared_error: 0.0498 - val_loss: 0.0362 - val_mean_squared_error: 0.0362 - lr: 0.0010
# Epoch 10/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0472 - mean_squared_error: 0.0472 - val_loss: 0.0351 - val_mean_squared_error: 0.0351 - lr: 0.0010
# Epoch 11/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0455 - mean_squared_error: 0.0455 - val_loss: 0.0339 - val_mean_squared_error: 0.0339 - lr: 0.0010
# Epoch 12/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0437 - mean_squared_error: 0.0437 - val_loss: 0.0320 - val_mean_squared_error: 0.0320 - lr: 0.0010
# Epoch 13/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0415 - mean_squared_error: 0.0415 - val_loss: 0.0306 - val_mean_squared_error: 0.0306 - lr: 0.0010
# Epoch 14/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0397 - mean_squared_error: 0.0397 - val_loss: 0.0294 - val_mean_squared_error: 0.0294 - lr: 0.0010
# Epoch 15/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0380 - mean_squared_error: 0.0380 - val_loss: 0.0294 - val_mean_squared_error: 0.0294 - lr: 0.0010
# Epoch 16/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0372 - mean_squared_error: 0.0372 - val_loss: 0.0282 - val_mean_squared_error: 0.0282 - lr: 0.0010
# Epoch 17/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0356 - mean_squared_error: 0.0356 - val_loss: 0.0272 - val_mean_squared_error: 0.0272 - lr: 0.0010
# Epoch 18/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0347 - mean_squared_error: 0.0347 - val_loss: 0.0263 - val_mean_squared_error: 0.0263 - lr: 0.0010
# Epoch 19/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0337 - mean_squared_error: 0.0337 - val_loss: 0.0258 - val_mean_squared_error: 0.0258 - lr: 0.0010
# Epoch 20/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0252 - val_mean_squared_error: 0.0252 - lr: 0.0010
# Epoch 21/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0321 - mean_squared_error: 0.0321 - val_loss: 0.0245 - val_mean_squared_error: 0.0245 - lr: 0.0010
# Epoch 22/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0241 - val_mean_squared_error: 0.0241 - lr: 0.0010
# Epoch 23/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.0238 - val_mean_squared_error: 0.0238 - lr: 0.0010
# Epoch 24/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0302 - mean_squared_error: 0.0302 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - lr: 0.0010
# Epoch 25/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0294 - mean_squared_error: 0.0294 - val_loss: 0.0230 - val_mean_squared_error: 0.0230 - lr: 0.0010
# Epoch 26/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0226 - val_mean_squared_error: 0.0226 - lr: 0.0010
# Epoch 27/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - lr: 0.0010
# Epoch 28/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0275 - mean_squared_error: 0.0275 - val_loss: 0.0218 - val_mean_squared_error: 0.0218 - lr: 0.0010
# Epoch 29/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 30/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0267 - mean_squared_error: 0.0267 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 31/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0263 - mean_squared_error: 0.0263 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - lr: 0.0010
# Epoch 32/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0258 - mean_squared_error: 0.0258 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - lr: 0.0010
# Epoch 33/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0255 - mean_squared_error: 0.0255 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - lr: 0.0010
# Epoch 34/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0254 - mean_squared_error: 0.0254 - val_loss: 0.0200 - val_mean_squared_error: 0.0200 - lr: 0.0010
# Epoch 35/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - lr: 0.0010
# Epoch 36/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0247 - mean_squared_error: 0.0247 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - lr: 0.0010
# Epoch 37/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0243 - mean_squared_error: 0.0243 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - lr: 0.0010
# Epoch 38/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0241 - mean_squared_error: 0.0241 - val_loss: 0.0192 - val_mean_squared_error: 0.0192 - lr: 0.0010
# Epoch 39/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0238 - mean_squared_error: 0.0238 - val_loss: 0.0190 - val_mean_squared_error: 0.0190 - lr: 0.0010
# Epoch 40/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0234 - mean_squared_error: 0.0234 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - lr: 0.0010
# Epoch 41/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0233 - mean_squared_error: 0.0233 - val_loss: 0.0188 - val_mean_squared_error: 0.0188 - lr: 0.0010
# Epoch 42/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0231 - mean_squared_error: 0.0231 - val_loss: 0.0181 - val_mean_squared_error: 0.0181 - lr: 0.0010
# Epoch 43/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0229 - mean_squared_error: 0.0229 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - lr: 0.0010
# Epoch 44/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0228 - mean_squared_error: 0.0228 - val_loss: 0.0180 - val_mean_squared_error: 0.0180 - lr: 0.0010
# Epoch 45/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0225 - mean_squared_error: 0.0225 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - lr: 0.0010
# Epoch 46/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0180 - val_mean_squared_error: 0.0180 - lr: 0.0010
# Epoch 47/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0222 - mean_squared_error: 0.0222 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - lr: 0.0010
# Epoch 48/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0179 - val_mean_squared_error: 0.0179 - lr: 0.0010
# Epoch 49/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0216 - mean_squared_error: 0.0216 - val_loss: 0.0173 - val_mean_squared_error: 0.0173 - lr: 0.0010
# Epoch 50/50
# 77/77 [==============================] - 0s 3ms/step - loss: 0.0217 - mean_squared_error: 0.0217 - val_loss: 0.0175 - val_mean_squared_error: 0.0175 - lr: 0.0010

# %% [markdown]
# # Compute labels and scores

# %%
true_labels = np.asarray(data_test_labels, dtype=np.intc)
labels = model.predict(data, data_test)
scores = model.anomaly_score(data, data_test)
perc = np.sum(labels) / labels.shape[0]

# %% [markdown]
# # Evaluation metrics for anomaly detection

# %%
compute_metrics(true_labels, scores, labels, compute_roc_auc=not CHECK_OVERFITTING, only_roc_auc=False)
# Out:
# ACCURACY SCORE:  0.9385775862068966
# PRECISION SCORE:  0.0075
# RECALL SCORE:  0.6
# F1 SCORE:  0.014814814814814815
# AVERAGE PRECISION SCORE:  0.011005277298156813
# PRECISION-RECALL AUC SCORE:  0.008107285616677153
# AUROC SCORE:  0.8423355415190263

# %% [markdown]
# # Confusion matrix

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, labels)
vw.plot_confusion_matrix(confusion_matrix)

# %% [markdown]
# # ROC curve

# %%
vw.plot_roc_curve(true_labels, scores)

# %% [markdown]
# # Precision-recall curve

# %%
vw.plot_precision_recall_curve(true_labels, scores)

# %% [markdown]
# # Assigned labels

# %%
vw.plot_univariate_time_series_predictions(dataframe, labels)

# %% [markdown]
# # Assigned scores

# %%
vw.plot_univariate_time_series_predictions(dataframe, scores)

# %% [markdown]
# # Data and predictions

# %%
predictions = model.predict_time_series(data[validation_slices[0]], data_test)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=True)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=False)

# %% [markdown]
# # Anomalies predictions as red dots

# %%
bars = vw.get_bars_indices_on_test_df(all_df,
                                      dataframe,
                                      PURE_DATA_KEY,
                                      GROUND_WINDOWS_PATH)
vw.plot_time_series_with_predicitons_bars(dataframe,
                                          labels,
                                          bars,
                                          pred_color='r')
