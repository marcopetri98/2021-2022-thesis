# %% [markdown]
# # Imports and constants

# %%
import os

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

import visualizer.Viewer as vw
from Metrics import compute_metrics, make_metric_plots
from models.time_series.anomaly.deep_learning.BraeiCNNBatch import BraeiCNNBatch
from reader.NABTimeSeriesReader import NABTimeSeriesReader

# DATASET 1: ambient_temperature_system_failure
# DATASET 2: nyc_taxi
VALIDATION_DIM = 0.19
DATASET_PATH = "data/dataset/"
DATASET = "nyc_taxi.csv"
PURE_DATA_KEY = "realKnownCause/nyc_taxi.csv"
GROUND_WINDOWS_PATH = "data/dataset/combined_windows.json"
# The number of normal samples that must lie between a normal slice and an anomaly
SAFETY_DIM = 50
MINIMUM_SLICE = 100
ALL_METRICS = True
LOAD_MODEL = False
CHECK_OVERFITTING = False


def preprocess(X) -> np.ndarray:
    return StandardScaler().fit_transform(X)

# %% [markdown]
# # Set seed for reproducibility

# %%
np.random.seed(57)
tf.random.set_seed(57)

# %% [markdown]
# # Load training and testing data

# %%
reader = NABTimeSeriesReader(DATASET_PATH)
all_df = reader.read(DATASET_PATH + DATASET).get_dataframe()
training, test = reader.train_test_split(train_perc=0.37).get_train_test_dataframes()

# Data used to train
data = preprocess(np.array(training["value"]).reshape((training["value"].shape[0], 1)))
data_labels = training["target"]

# Data used to test
data_test = preprocess(np.array(test["value"]).reshape((test["value"].shape[0], 1)))
data_test_labels = test["target"]

# Data used to evaluate
dataframe = test.copy()
dataframe["value"] = data_test

if CHECK_OVERFITTING:
    data_test = preprocess(np.array(training["value"]).reshape(training["value"].shape[0], 1))
    data_test_labels = training["target"]
    dataframe = training.copy()
    dataframe["value"] = data_test

# %% [markdown]
# # Set slices on which to train and validate
#
# In each case we use a self-supervised approach. The models are built to be able to correctly reproduce normal samples of the data. Therefore, from the training dataset, we want to exclude all possible anomalies and their neighbouring points not to learn anomalies patterns. In such a way, we aim the model to produce big mispredictions for those points that are anomalies. Given these statements, from training and validation set we extract slices without anomalies.

# %%
# Create the slices of the trainig data
change_idx = np.where(np.array(data_labels[:-1]) != np.array(data_labels[1:]))
change_idx = np.array(change_idx) + 1
change_idx = change_idx.reshape(change_idx.shape[1])
change_idx = np.concatenate((np.array([0]), change_idx))
normal_slices = []
anomaly_slices = []
for i in range(len(change_idx)):
    start = change_idx[i]
    if i < len(change_idx) -1:
        stop = change_idx[i+1]
    else:
        stop = data.shape[0]
    
    if data_labels[change_idx[i]] == 1:
        anomaly_slices.append(slice(start, stop))
    else:
        normal_slices.append(slice(start, stop))

print("The slices before safety check: %s" % normal_slices)

for i in range(len(normal_slices)):
    start_first = False
    end_last = False
    if normal_slices[i].start == 0:
        start_first = True
    if normal_slices[i].stop == data.shape[0]:
        end_last = True
    
    if not start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)
    elif not start_first and end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop,
                                 normal_slices[i].step)
    elif start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)

print("The slices after safety check: %s" % normal_slices)
# Out:
# The slices before safety check: [slice(0, 3819, None)]
# The slices after safety check: [slice(0, 3819, None)]

# %% [markdown]
# # Computation of training and validation slices
#
# Given the slices of normal points on which we will train and validate the model, we need to compute the slices characterizing the training and the validation samples of the dataset. To do so, we will need to iterate over the normal slices to compute the number of points in it. Then, we compute the number of points required for the validation set and from this number we will compute the validation slices. However, we risk to compute slices of only 1 sample in some extreme cases. Therefore, we will control that each slice is at least of `MINIMUM_SLICE` samples.

# %%
# Gets the step (equal for all slices)
step = normal_slices[0].step if normal_slices[0].step is not None else 1
ok_normal_slices = []
tot_samples = 0
for i in range(len(normal_slices)):
    samples = int((normal_slices[i].stop - normal_slices[i].start) / step)
    if samples > MINIMUM_SLICE:
        tot_samples += samples
        ok_normal_slices.append(normal_slices[i])
        
valid_points = tot_samples * VALIDATION_DIM
training_slices = []
validation_slices = []
tot_valid = 0
for i in reversed(range(len(ok_normal_slices))):
    if tot_valid >= valid_points:
        training_slices.append(ok_normal_slices[i])
    else:
        samples = int((ok_normal_slices[i].stop - ok_normal_slices[i].start) / step)
        needed_points = valid_points - tot_valid

        if samples < needed_points:
            validation_slices.append(ok_normal_slices[i])
        else:
            train_stop = int(ok_normal_slices[i].stop - needed_points * step)
            slice_train = slice(ok_normal_slices[i].start,
                                train_stop,
                                ok_normal_slices[i].step)
            slice_valid = slice(train_stop,
                                ok_normal_slices[i].stop,
                                ok_normal_slices[i].step)
            
            # If points are enough, they are added to lists
            if (slice_train.stop - slice_train.start) / step >= MINIMUM_SLICE:
                training_slices.append(slice_train)
            if (slice_valid.stop - slice_valid.start) / step >= MINIMUM_SLICE:
                validation_slices.append(slice_valid)
                
            # Since in this else we enter only at the last slice, set up to exit in case minimum
            # slice is not reached
            tot_valid = valid_points + 1
            
training_slices.reverse()
validation_slices.reverse()

print("The training slices are: %s" % training_slices)
print("The validation slices are: %s" % validation_slices)
# Out:
# The training slices are: [slice(0, 3093, None)]
# The validation slices are: [slice(3093, 3819, None)]

# %% [markdown]
# # Load or fit the model

# %%
model = BraeiCNNBatch(window=30,
                      max_epochs=100,
                      batch_size=32,
                      predict_validation=0.1982,
                      batch_divide_training=True,
                      filename="nyc_cnnb_paper")
if LOAD_MODEL:
    model.load_model("data/nn_models/nyc_cnnb_paper")
else:
    model.fit(data, training_slices, validation_slices, data_labels)
# Out:
# [2022/05/17 18:10:20] WARNING: Data.shape[0] - window must be a multiple of batch to build the spatial data. I.e.,(Data.shape[0] - window)%batch_size == 0
# Model: "batch_cnn_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 30, 1)]           0
#
#  conv1d_1 (Conv1D)           (None, 30, 256)           1024
#
#  batch_1 (BatchNormalization  (None, 30, 256)          1024
#  )
#
#  conv1d_2 (Conv1D)           (None, 30, 256)           196864
#
#  batch_2 (BatchNormalization  (None, 30, 256)          1024
#  )
#
#  flatten (Flatten)           (None, 7680)              0
#
#  final_dense (Dense)         (None, 50)                384050
#
#  output (Dense)              (None, 1)                 51
#
# =================================================================
# Total params: 584,037
# Trainable params: 583,013
# Non-trainable params: 1,024
# _________________________________________________________________
# Epoch 1/100
# 77/77 [==============================] - 4s 35ms/step - loss: 3.8830 - mean_squared_error: 3.8830 - val_loss: 0.6176 - val_mean_squared_error: 0.6176 - lr: 0.0010
# Epoch 2/100
# 77/77 [==============================] - 2s 28ms/step - loss: 1.2192 - mean_squared_error: 1.2192 - val_loss: 0.8840 - val_mean_squared_error: 0.8840 - lr: 0.0010
# Epoch 3/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.4009 - mean_squared_error: 0.4009 - val_loss: 0.6695 - val_mean_squared_error: 0.6695 - lr: 0.0010
# Epoch 4/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.2265 - mean_squared_error: 0.2265 - val_loss: 0.5354 - val_mean_squared_error: 0.5354 - lr: 0.0010
# Epoch 5/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.3508 - mean_squared_error: 0.3508 - val_loss: 0.3262 - val_mean_squared_error: 0.3262 - lr: 0.0010
# Epoch 6/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.1501 - mean_squared_error: 0.1501 - val_loss: 0.2415 - val_mean_squared_error: 0.2415 - lr: 0.0010
# Epoch 7/100
# 77/77 [==============================] - 5s 64ms/step - loss: 0.0857 - mean_squared_error: 0.0857 - val_loss: 0.1467 - val_mean_squared_error: 0.1467 - lr: 0.0010
# Epoch 8/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0456 - mean_squared_error: 0.0456 - val_loss: 0.0664 - val_mean_squared_error: 0.0664 - lr: 0.0010
# Epoch 9/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0391 - mean_squared_error: 0.0391 - val_loss: 0.0516 - val_mean_squared_error: 0.0516 - lr: 0.0010
# Epoch 10/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0408 - mean_squared_error: 0.0408 - val_loss: 0.0440 - val_mean_squared_error: 0.0440 - lr: 0.0010
# Epoch 11/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0379 - mean_squared_error: 0.0379 - val_loss: 0.0363 - val_mean_squared_error: 0.0363 - lr: 0.0010
# Epoch 12/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0471 - val_mean_squared_error: 0.0471 - lr: 0.0010
# Epoch 13/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0431 - mean_squared_error: 0.0431 - val_loss: 0.0249 - val_mean_squared_error: 0.0249 - lr: 0.0010
# Epoch 14/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0249 - mean_squared_error: 0.0249 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0010
# Epoch 15/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.0230 - mean_squared_error: 0.0230 - val_loss: 0.0313 - val_mean_squared_error: 0.0313 - lr: 0.0010
# Epoch 16/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.0224 - mean_squared_error: 0.0224 - val_loss: 0.0304 - val_mean_squared_error: 0.0304 - lr: 0.0010
# Epoch 17/100
# 77/77 [==============================] - 4s 57ms/step - loss: 0.0342 - mean_squared_error: 0.0342 - val_loss: 0.0488 - val_mean_squared_error: 0.0488 - lr: 0.0010
# Epoch 18/100
# 77/77 [==============================] - 4s 48ms/step - loss: 0.0453 - mean_squared_error: 0.0453 - val_loss: 0.0266 - val_mean_squared_error: 0.0266 - lr: 0.0010
# Epoch 19/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.0265 - mean_squared_error: 0.0265 - val_loss: 0.0246 - val_mean_squared_error: 0.0246 - lr: 0.0010
# Epoch 20/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.0242 - mean_squared_error: 0.0242 - val_loss: 0.0278 - val_mean_squared_error: 0.0278 - lr: 0.0010
# Epoch 21/100
# 77/77 [==============================] - 2s 32ms/step - loss: 0.0201 - mean_squared_error: 0.0201 - val_loss: 0.0253 - val_mean_squared_error: 0.0253 - lr: 0.0010
# Epoch 22/100
# 77/77 [==============================] - 2s 32ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0244 - val_mean_squared_error: 0.0244 - lr: 0.0010
# Epoch 23/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0199 - val_mean_squared_error: 0.0199 - lr: 0.0010
# Epoch 24/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.0148 - mean_squared_error: 0.0148 - val_loss: 0.0186 - val_mean_squared_error: 0.0186 - lr: 0.0010
# Epoch 25/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.0205 - mean_squared_error: 0.0205 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0010
# Epoch 26/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.0188 - mean_squared_error: 0.0188 - val_loss: 0.0195 - val_mean_squared_error: 0.0195 - lr: 0.0010
# Epoch 27/100
# 77/77 [==============================] - 4s 54ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0176 - val_mean_squared_error: 0.0176 - lr: 0.0010
# Epoch 28/100
# 77/77 [==============================] - 2s 32ms/step - loss: 0.0161 - mean_squared_error: 0.0161 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - lr: 0.0010
# Epoch 29/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0212 - mean_squared_error: 0.0212 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - lr: 0.0010
# Epoch 30/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0201 - val_mean_squared_error: 0.0201 - lr: 0.0010
# Epoch 31/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0183 - val_mean_squared_error: 0.0183 - lr: 0.0010
# Epoch 32/100
# 77/77 [==============================] - 3s 33ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0182 - val_mean_squared_error: 0.0182 - lr: 0.0010
# Epoch 33/100
# 77/77 [==============================] - 5s 63ms/step - loss: 0.0146 - mean_squared_error: 0.0146 - val_loss: 0.0237 - val_mean_squared_error: 0.0237 - lr: 0.0010
# Epoch 34/100
# 77/77 [==============================] - 3s 34ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0216 - val_mean_squared_error: 0.0216 - lr: 0.0010
# Epoch 35/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - lr: 0.0010
# Epoch 36/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - lr: 0.0010
# Epoch 37/100
# 77/77 [==============================] - 3s 35ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0174 - val_mean_squared_error: 0.0174 - lr: 0.0010
# Epoch 38/100
# 77/77 [==============================] - 2s 30ms/step - loss: 0.0150 - mean_squared_error: 0.0150 - val_loss: 0.0198 - val_mean_squared_error: 0.0198 - lr: 0.0010
# Epoch 39/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - lr: 0.0010
# Epoch 40/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - lr: 0.0010
# Epoch 41/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0116 - mean_squared_error: 0.0116 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - lr: 0.0010
# Epoch 42/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - lr: 0.0010
# Epoch 43/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - lr: 0.0010
# Epoch 44/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0145 - mean_squared_error: 0.0145 - val_loss: 0.0134 - val_mean_squared_error: 0.0134 - lr: 0.0010
# Epoch 45/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0200 - val_mean_squared_error: 0.0200 - lr: 0.0010
# Epoch 46/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0133 - mean_squared_error: 0.0133 - val_loss: 0.0149 - val_mean_squared_error: 0.0149 - lr: 0.0010
# Epoch 47/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0130 - mean_squared_error: 0.0130 - val_loss: 0.0161 - val_mean_squared_error: 0.0161 - lr: 0.0010
# Epoch 48/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0167 - val_mean_squared_error: 0.0167 - lr: 0.0010
# Epoch 49/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 0.0165 - val_mean_squared_error: 0.0165 - lr: 0.0010
# Epoch 50/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0151 - val_mean_squared_error: 0.0151 - lr: 0.0010
# Epoch 51/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0126 - mean_squared_error: 0.0126 - val_loss: 0.0193 - val_mean_squared_error: 0.0193 - lr: 0.0010
# Epoch 52/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0113 - mean_squared_error: 0.0113 - val_loss: 0.0187 - val_mean_squared_error: 0.0187 - lr: 0.0010
# Epoch 53/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.0118 - mean_squared_error: 0.0118 - val_loss: 0.0181 - val_mean_squared_error: 0.0181 - lr: 0.0010
# Epoch 54/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0124 - mean_squared_error: 0.0124 - val_loss: 0.0152 - val_mean_squared_error: 0.0152 - lr: 0.0010
# Epoch 55/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0117 - mean_squared_error: 0.0117 - val_loss: 0.0174 - val_mean_squared_error: 0.0174 - lr: 0.0010
# Epoch 56/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0103 - mean_squared_error: 0.0103 - val_loss: 0.0136 - val_mean_squared_error: 0.0136 - lr: 0.0010
# Epoch 57/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.0106 - mean_squared_error: 0.0106 - val_loss: 0.0178 - val_mean_squared_error: 0.0178 - lr: 0.0010
# Epoch 58/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - lr: 0.0010
# Epoch 59/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0169 - val_mean_squared_error: 0.0169 - lr: 0.0010
# Epoch 60/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0177 - val_mean_squared_error: 0.0177 - lr: 0.0010
# Epoch 61/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0153 - val_mean_squared_error: 0.0153 - lr: 0.0010
# Epoch 62/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0148 - val_mean_squared_error: 0.0148 - lr: 0.0010
# Epoch 63/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0096 - mean_squared_error: 0.0096 - val_loss: 0.0197 - val_mean_squared_error: 0.0197 - lr: 0.0010
# Epoch 64/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.0102 - mean_squared_error: 0.0102 - val_loss: 0.0340 - val_mean_squared_error: 0.0340 - lr: 0.0010
# Epoch 65/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - lr: 1.0000e-04
# Epoch 66/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 67/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - lr: 1.0000e-04
# Epoch 68/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0123 - val_mean_squared_error: 0.0123 - lr: 1.0000e-04
# Epoch 69/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - lr: 1.0000e-04
# Epoch 70/100
# 77/77 [==============================] - 4s 46ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0125 - val_mean_squared_error: 0.0125 - lr: 1.0000e-04
# Epoch 71/100
# 77/77 [==============================] - 4s 47ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 72/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0124 - val_mean_squared_error: 0.0124 - lr: 1.0000e-04
# Epoch 73/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - lr: 1.0000e-04
# Epoch 74/100
# 77/77 [==============================] - 3s 36ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 75/100
# 77/77 [==============================] - 2s 31ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - lr: 1.0000e-04
# Epoch 76/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 77/100
# 77/77 [==============================] - 3s 37ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - lr: 1.0000e-04
# Epoch 78/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 79/100
# 77/77 [==============================] - 2s 28ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - lr: 1.0000e-04
# Epoch 80/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - lr: 1.0000e-04
# Epoch 81/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - lr: 1.0000e-04
# Epoch 82/100
# 77/77 [==============================] - 2s 26ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - lr: 1.0000e-04
# Epoch 83/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - lr: 1.0000e-04
# Epoch 84/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 85/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0121 - val_mean_squared_error: 0.0121 - lr: 1.0000e-04
# Epoch 86/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0119 - val_mean_squared_error: 0.0119 - lr: 1.0000e-04
# Epoch 87/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - lr: 1.0000e-04
# Epoch 88/100
# 77/77 [==============================] - 4s 48ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - lr: 1.0000e-04
# Epoch 89/100
# 77/77 [==============================] - 2s 29ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 90/100
# 77/77 [==============================] - 2s 27ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0114 - val_mean_squared_error: 0.0114 - lr: 1.0000e-04
# Epoch 91/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 92/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 93/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 1.0000e-04
# Epoch 94/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0118 - val_mean_squared_error: 0.0118 - lr: 1.0000e-04
# Epoch 95/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0122 - val_mean_squared_error: 0.0122 - lr: 1.0000e-04
# Epoch 96/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0126 - val_mean_squared_error: 0.0126 - lr: 1.0000e-04
# Epoch 97/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0116 - val_mean_squared_error: 0.0116 - lr: 1.0000e-04
# Epoch 98/100
# 77/77 [==============================] - 2s 25ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - lr: 1.0000e-04
# Epoch 99/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0117 - val_mean_squared_error: 0.0117 - lr: 1.0000e-04
# Epoch 100/100
# 77/77 [==============================] - 2s 24ms/step - loss: 0.0041 - mean_squared_error: 0.0041 - val_loss: 0.0115 - val_mean_squared_error: 0.0115 - lr: 1.0000e-04

# %% [markdown]
# # Compute labels and scores

# %%
true_labels = np.asarray(data_test_labels, dtype=np.intc)
labels = model.predict(data, data_test)
scores = model.anomaly_score(data, data_test)
perc = np.sum(labels) / labels.shape[0]

# %% [markdown]
# # Evaluation metrics for anomaly detection

# %%
compute_metrics(true_labels, scores, labels, compute_roc_auc=not CHECK_OVERFITTING, only_roc_auc=False)
# Out:
# ACCURACY SCORE:  0.9786186740501461
# PRECISION SCORE:  0.007352941176470588
# RECALL SCORE:  0.2
# F1 SCORE:  0.014184397163120567
# AVERAGE PRECISION SCORE:  0.006092655463517943
# PRECISION-RECALL AUC SCORE:  0.004493114942573101
# AUROC SCORE:  0.9017857142857143

# %% [markdown]
# # Confusion matrix

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, labels)
vw.plot_confusion_matrix(confusion_matrix)

# %% [markdown]
# # ROC curve

# %%
vw.plot_roc_curve(true_labels, scores)

# %% [markdown]
# # Precision-recall curve

# %%
vw.plot_precision_recall_curve(true_labels, scores)

# %% [markdown]
# # Assigned labels

# %%
vw.plot_univariate_time_series_predictions(dataframe, labels)

# %% [markdown]
# # Assigned scores

# %%
vw.plot_univariate_time_series_predictions(dataframe, scores)

# %% [markdown]
# # Data and predictions

# %%
predictions = model.predict_time_series(data[validation_slices[0]], data_test)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=True)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=False)

# %% [markdown]
# # Anomalies predictions as red dots

# %%
bars = vw.get_bars_indices_on_test_df(all_df,
                                      dataframe,
                                      PURE_DATA_KEY,
                                      GROUND_WINDOWS_PATH)
vw.plot_time_series_with_predicitons_bars(dataframe,
                                          labels,
                                          bars,
                                          pred_color='r')
