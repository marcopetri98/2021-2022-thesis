# %% [markdown]
# # Imports and constants

# %%
import os

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

import visualizer.Viewer as vw
from Metrics import compute_metrics, make_metric_plots
from models.time_series.anomaly.deep_learning.BraeiGRU import BraeiGRU
from reader.NABTimeSeriesReader import NABTimeSeriesReader

# DATASET 1: ambient_temperature_system_failure
# DATASET 2: nyc_taxi
VALIDATION_DIM = 0.19
DATASET_PATH = "data/dataset/"
DATASET = "nyc_taxi.csv"
PURE_DATA_KEY = "realKnownCause/nyc_taxi.csv"
GROUND_WINDOWS_PATH = "data/dataset/combined_windows.json"
# The number of normal samples that must lie between a normal slice and an anomaly
SAFETY_DIM = 50
MINIMUM_SLICE = 100
ALL_METRICS = True
LOAD_MODEL = False
CHECK_OVERFITTING = False


def preprocess(X) -> np.ndarray:
    return StandardScaler().fit_transform(X)

# %% [markdown]
# # Set seed for reproducibility

# %%
np.random.seed(57)
tf.random.set_seed(57)

# %% [markdown]
# # Load training and testing data

# %%
reader = NABTimeSeriesReader(DATASET_PATH)
all_df = reader.read(DATASET_PATH + DATASET).get_dataframe()
training, test = reader.train_test_split(train_perc=0.37).get_train_test_dataframes()

# Data used to train
data = preprocess(np.array(training["value"]).reshape((training["value"].shape[0], 1)))
data_labels = training["target"]

# Data used to test
data_test = preprocess(np.array(test["value"]).reshape((test["value"].shape[0], 1)))
data_test_labels = test["target"]

# Data used to evaluate
dataframe = test.copy()
dataframe["value"] = data_test

if CHECK_OVERFITTING:
    data_test = preprocess(np.array(training["value"]).reshape(training["value"].shape[0], 1))
    data_test_labels = training["target"]
    dataframe = training.copy()
    dataframe["value"] = data_test

# %% [markdown]
# # Set slices on which to train and validate
#
# In each case we use a self-supervised approach. The models are built to be able to correctly reproduce normal samples of the data. Therefore, from the training dataset, we want to exclude all possible anomalies and their neighbouring points not to learn anomalies patterns. In such a way, we aim the model to produce big mispredictions for those points that are anomalies. Given these statements, from training and validation set we extract slices without anomalies.

# %%
# Create the slices of the trainig data
change_idx = np.where(np.array(data_labels[:-1]) != np.array(data_labels[1:]))
change_idx = np.array(change_idx) + 1
change_idx = change_idx.reshape(change_idx.shape[1])
change_idx = np.concatenate((np.array([0]), change_idx))
normal_slices = []
anomaly_slices = []
for i in range(len(change_idx)):
    start = change_idx[i]
    if i < len(change_idx) -1:
        stop = change_idx[i+1]
    else:
        stop = data.shape[0]
    
    if data_labels[change_idx[i]] == 1:
        anomaly_slices.append(slice(start, stop))
    else:
        normal_slices.append(slice(start, stop))

print("The slices before safety check: %s" % normal_slices)

for i in range(len(normal_slices)):
    start_first = False
    end_last = False
    if normal_slices[i].start == 0:
        start_first = True
    if normal_slices[i].stop == data.shape[0]:
        end_last = True
    
    if not start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)
    elif not start_first and end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop,
                                 normal_slices[i].step)
    elif start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)

print("The slices after safety check: %s" % normal_slices)
# Out:
# The slices before safety check: [slice(0, 3819, None)]
# The slices after safety check: [slice(0, 3819, None)]

# %% [markdown]
# # Computation of training and validation slices
#
# Given the slices of normal points on which we will train and validate the model, we need to compute the slices characterizing the training and the validation samples of the dataset. To do so, we will need to iterate over the normal slices to compute the number of points in it. Then, we compute the number of points required for the validation set and from this number we will compute the validation slices. However, we risk to compute slices of only 1 sample in some extreme cases. Therefore, we will control that each slice is at least of `MINIMUM_SLICE` samples.

# %%
# Gets the step (equal for all slices)
step = normal_slices[0].step if normal_slices[0].step is not None else 1
ok_normal_slices = []
tot_samples = 0
for i in range(len(normal_slices)):
    samples = int((normal_slices[i].stop - normal_slices[i].start) / step)
    if samples > MINIMUM_SLICE:
        tot_samples += samples
        ok_normal_slices.append(normal_slices[i])
        
valid_points = tot_samples * VALIDATION_DIM
training_slices = []
validation_slices = []
tot_valid = 0
for i in reversed(range(len(ok_normal_slices))):
    if tot_valid >= valid_points:
        training_slices.append(ok_normal_slices[i])
    else:
        samples = int((ok_normal_slices[i].stop - ok_normal_slices[i].start) / step)
        needed_points = valid_points - tot_valid

        if samples < needed_points:
            validation_slices.append(ok_normal_slices[i])
        else:
            train_stop = int(ok_normal_slices[i].stop - needed_points * step)
            slice_train = slice(ok_normal_slices[i].start,
                                train_stop,
                                ok_normal_slices[i].step)
            slice_valid = slice(train_stop,
                                ok_normal_slices[i].stop,
                                ok_normal_slices[i].step)
            
            # If points are enough, they are added to lists
            if (slice_train.stop - slice_train.start) / step >= MINIMUM_SLICE:
                training_slices.append(slice_train)
            if (slice_valid.stop - slice_valid.start) / step >= MINIMUM_SLICE:
                validation_slices.append(slice_valid)
                
            # Since in this else we enter only at the last slice, set up to exit in case minimum
            # slice is not reached
            tot_valid = valid_points + 1
            
training_slices.reverse()
validation_slices.reverse()

print("The training slices are: %s" % training_slices)
print("The validation slices are: %s" % validation_slices)
# Out:
# The training slices are: [slice(0, 3093, None)]
# The validation slices are: [slice(3093, 3819, None)]

# %% [markdown]
# # Load or fit the model

# %%
model = BraeiGRU(window=30,
                 max_epochs=100,
                 batch_size=32,
                 predict_validation=0.1982,
                 batch_divide_training=True,
                 filename="nyc_gru_paper")
if LOAD_MODEL:
    model.load_model("data/nn_models/nyc_gru_paper")
else:
    model.fit(data, training_slices, validation_slices, data_labels)
# Out:
# [2022/05/17 16:23:00] WARNING: Data.shape[0] - window must be a multiple of batch to build the spatial data. I.e.,(Data.shape[0] - window)%batch_size == 0
# Model: "gru_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(32, 30, 1)]             0
#
#  stateful_gru_1 (GRU)        (32, 30, 4)               84
#
#  stateful_gru_2 (GRU)        (32, 4)                   120
#
#  output (Dense)              (32, 1)                   5
#
# =================================================================
# Total params: 209
# Trainable params: 209
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 77/77 [==============================] - 6s 29ms/step - loss: 1.0436 - mean_squared_error: 1.0436 - val_loss: 0.5207 - val_mean_squared_error: 0.5207 - lr: 0.0010
# Epoch 2/100
# 77/77 [==============================] - 1s 16ms/step - loss: 0.4021 - mean_squared_error: 0.4021 - val_loss: 0.2136 - val_mean_squared_error: 0.2136 - lr: 0.0010
# Epoch 3/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.2362 - mean_squared_error: 0.2362 - val_loss: 0.1427 - val_mean_squared_error: 0.1427 - lr: 0.0010
# Epoch 4/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.1726 - mean_squared_error: 0.1726 - val_loss: 0.1033 - val_mean_squared_error: 0.1033 - lr: 0.0010
# Epoch 5/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.1330 - mean_squared_error: 0.1330 - val_loss: 0.0809 - val_mean_squared_error: 0.0809 - lr: 0.0010
# Epoch 6/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.1067 - mean_squared_error: 0.1067 - val_loss: 0.0665 - val_mean_squared_error: 0.0665 - lr: 0.0010
# Epoch 7/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0899 - mean_squared_error: 0.0899 - val_loss: 0.0577 - val_mean_squared_error: 0.0577 - lr: 0.0010
# Epoch 8/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0785 - mean_squared_error: 0.0785 - val_loss: 0.0510 - val_mean_squared_error: 0.0510 - lr: 0.0010
# Epoch 9/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0695 - mean_squared_error: 0.0695 - val_loss: 0.0438 - val_mean_squared_error: 0.0438 - lr: 0.0010
# Epoch 10/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0626 - mean_squared_error: 0.0626 - val_loss: 0.0432 - val_mean_squared_error: 0.0432 - lr: 0.0010
# Epoch 11/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0573 - mean_squared_error: 0.0573 - val_loss: 0.0371 - val_mean_squared_error: 0.0371 - lr: 0.0010
# Epoch 12/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0524 - mean_squared_error: 0.0524 - val_loss: 0.0346 - val_mean_squared_error: 0.0346 - lr: 0.0010
# Epoch 13/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0487 - mean_squared_error: 0.0487 - val_loss: 0.0322 - val_mean_squared_error: 0.0322 - lr: 0.0010
# Epoch 14/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0454 - mean_squared_error: 0.0454 - val_loss: 0.0304 - val_mean_squared_error: 0.0304 - lr: 0.0010
# Epoch 15/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0427 - mean_squared_error: 0.0427 - val_loss: 0.0299 - val_mean_squared_error: 0.0299 - lr: 0.0010
# Epoch 16/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0405 - mean_squared_error: 0.0405 - val_loss: 0.0271 - val_mean_squared_error: 0.0271 - lr: 0.0010
# Epoch 17/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0387 - mean_squared_error: 0.0387 - val_loss: 0.0257 - val_mean_squared_error: 0.0257 - lr: 0.0010
# Epoch 18/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0373 - mean_squared_error: 0.0373 - val_loss: 0.0251 - val_mean_squared_error: 0.0251 - lr: 0.0010
# Epoch 19/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0361 - mean_squared_error: 0.0361 - val_loss: 0.0249 - val_mean_squared_error: 0.0249 - lr: 0.0010
# Epoch 20/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0352 - mean_squared_error: 0.0352 - val_loss: 0.0243 - val_mean_squared_error: 0.0243 - lr: 0.0010
# Epoch 21/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0345 - mean_squared_error: 0.0345 - val_loss: 0.0240 - val_mean_squared_error: 0.0240 - lr: 0.0010
# Epoch 22/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0341 - mean_squared_error: 0.0341 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - lr: 0.0010
# Epoch 23/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0337 - mean_squared_error: 0.0337 - val_loss: 0.0229 - val_mean_squared_error: 0.0229 - lr: 0.0010
# Epoch 24/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0333 - mean_squared_error: 0.0333 - val_loss: 0.0232 - val_mean_squared_error: 0.0232 - lr: 0.0010
# Epoch 25/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0330 - mean_squared_error: 0.0330 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - lr: 0.0010
# Epoch 26/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0328 - mean_squared_error: 0.0328 - val_loss: 0.0230 - val_mean_squared_error: 0.0230 - lr: 0.0010
# Epoch 27/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0326 - mean_squared_error: 0.0326 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - lr: 0.0010
# Epoch 28/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0327 - mean_squared_error: 0.0327 - val_loss: 0.0233 - val_mean_squared_error: 0.0233 - lr: 0.0010
# Epoch 29/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0226 - val_mean_squared_error: 0.0226 - lr: 0.0010
# Epoch 30/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0321 - mean_squared_error: 0.0321 - val_loss: 0.0245 - val_mean_squared_error: 0.0245 - lr: 0.0010
# Epoch 31/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0226 - val_mean_squared_error: 0.0226 - lr: 0.0010
# Epoch 32/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0320 - mean_squared_error: 0.0320 - val_loss: 0.0227 - val_mean_squared_error: 0.0227 - lr: 0.0010
# Epoch 33/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0318 - mean_squared_error: 0.0318 - val_loss: 0.0221 - val_mean_squared_error: 0.0221 - lr: 0.0010
# Epoch 34/100
# 77/77 [==============================] - 1s 16ms/step - loss: 0.0316 - mean_squared_error: 0.0316 - val_loss: 0.0240 - val_mean_squared_error: 0.0240 - lr: 0.0010
# Epoch 35/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 0.0222 - val_mean_squared_error: 0.0222 - lr: 0.0010
# Epoch 36/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0317 - mean_squared_error: 0.0317 - val_loss: 0.0252 - val_mean_squared_error: 0.0252 - lr: 0.0010
# Epoch 37/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0322 - mean_squared_error: 0.0322 - val_loss: 0.0218 - val_mean_squared_error: 0.0218 - lr: 0.0010
# Epoch 38/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0314 - mean_squared_error: 0.0314 - val_loss: 0.0224 - val_mean_squared_error: 0.0224 - lr: 0.0010
# Epoch 39/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0316 - mean_squared_error: 0.0316 - val_loss: 0.0219 - val_mean_squared_error: 0.0219 - lr: 0.0010
# Epoch 40/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0313 - mean_squared_error: 0.0313 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - lr: 0.0010
# Epoch 41/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0311 - mean_squared_error: 0.0311 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - lr: 0.0010
# Epoch 42/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0215 - val_mean_squared_error: 0.0215 - lr: 0.0010
# Epoch 43/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0309 - mean_squared_error: 0.0309 - val_loss: 0.0229 - val_mean_squared_error: 0.0229 - lr: 0.0010
# Epoch 44/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0309 - mean_squared_error: 0.0309 - val_loss: 0.0224 - val_mean_squared_error: 0.0224 - lr: 0.0010
# Epoch 45/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.0223 - val_mean_squared_error: 0.0223 - lr: 0.0010
# Epoch 46/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0310 - mean_squared_error: 0.0310 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - lr: 0.0010
# Epoch 47/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0308 - mean_squared_error: 0.0308 - val_loss: 0.0228 - val_mean_squared_error: 0.0228 - lr: 0.0010
# Epoch 48/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0307 - mean_squared_error: 0.0307 - val_loss: 0.0233 - val_mean_squared_error: 0.0233 - lr: 0.0010
# Epoch 49/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0309 - mean_squared_error: 0.0309 - val_loss: 0.0235 - val_mean_squared_error: 0.0235 - lr: 0.0010
# Epoch 50/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0306 - mean_squared_error: 0.0306 - val_loss: 0.0221 - val_mean_squared_error: 0.0221 - lr: 0.0010
# Epoch 51/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0305 - mean_squared_error: 0.0305 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - lr: 0.0010
# Epoch 52/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0305 - mean_squared_error: 0.0305 - val_loss: 0.0218 - val_mean_squared_error: 0.0218 - lr: 0.0010
# Epoch 53/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - lr: 0.0010
# Epoch 54/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 55/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0305 - mean_squared_error: 0.0305 - val_loss: 0.0214 - val_mean_squared_error: 0.0214 - lr: 0.0010
# Epoch 56/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0302 - mean_squared_error: 0.0302 - val_loss: 0.0223 - val_mean_squared_error: 0.0223 - lr: 0.0010
# Epoch 57/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0305 - mean_squared_error: 0.0305 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 58/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.0224 - val_mean_squared_error: 0.0224 - lr: 0.0010
# Epoch 59/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 60/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0300 - mean_squared_error: 0.0300 - val_loss: 0.0220 - val_mean_squared_error: 0.0220 - lr: 0.0010
# Epoch 61/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 62/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0304 - mean_squared_error: 0.0304 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - lr: 0.0010
# Epoch 63/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0300 - mean_squared_error: 0.0300 - val_loss: 0.0216 - val_mean_squared_error: 0.0216 - lr: 0.0010
# Epoch 64/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - lr: 0.0010
# Epoch 65/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0223 - val_mean_squared_error: 0.0223 - lr: 0.0010
# Epoch 66/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0298 - mean_squared_error: 0.0298 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - lr: 0.0010
# Epoch 67/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0300 - mean_squared_error: 0.0300 - val_loss: 0.0204 - val_mean_squared_error: 0.0204 - lr: 0.0010
# Epoch 68/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0298 - mean_squared_error: 0.0298 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 0.0010
# Epoch 69/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0296 - mean_squared_error: 0.0296 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - lr: 0.0010
# Epoch 70/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0301 - mean_squared_error: 0.0301 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - lr: 0.0010
# Epoch 71/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 72/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0294 - mean_squared_error: 0.0294 - val_loss: 0.0217 - val_mean_squared_error: 0.0217 - lr: 0.0010
# Epoch 73/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0299 - mean_squared_error: 0.0299 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - lr: 0.0010
# Epoch 74/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0293 - mean_squared_error: 0.0293 - val_loss: 0.0212 - val_mean_squared_error: 0.0212 - lr: 0.0010
# Epoch 75/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0293 - mean_squared_error: 0.0293 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - lr: 0.0010
# Epoch 76/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0207 - val_mean_squared_error: 0.0207 - lr: 0.0010
# Epoch 77/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - lr: 0.0010
# Epoch 78/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0292 - mean_squared_error: 0.0292 - val_loss: 0.0231 - val_mean_squared_error: 0.0231 - lr: 0.0010
# Epoch 79/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0291 - mean_squared_error: 0.0291 - val_loss: 0.0210 - val_mean_squared_error: 0.0210 - lr: 0.0010
# Epoch 80/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0293 - mean_squared_error: 0.0293 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - lr: 0.0010
# Epoch 81/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - lr: 0.0010
# Epoch 82/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0289 - mean_squared_error: 0.0289 - val_loss: 0.0199 - val_mean_squared_error: 0.0199 - lr: 0.0010
# Epoch 83/100
# 77/77 [==============================] - 1s 15ms/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0203 - val_mean_squared_error: 0.0203 - lr: 0.0010
# Epoch 84/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0290 - mean_squared_error: 0.0290 - val_loss: 0.0213 - val_mean_squared_error: 0.0213 - lr: 0.0010
# Epoch 85/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - lr: 0.0010
# Epoch 86/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0288 - mean_squared_error: 0.0288 - val_loss: 0.0206 - val_mean_squared_error: 0.0206 - lr: 0.0010
# Epoch 87/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0202 - val_mean_squared_error: 0.0202 - lr: 0.0010
# Epoch 88/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0198 - val_mean_squared_error: 0.0198 - lr: 0.0010
# Epoch 89/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0287 - mean_squared_error: 0.0287 - val_loss: 0.0209 - val_mean_squared_error: 0.0209 - lr: 0.0010
# Epoch 90/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - lr: 0.0010
# Epoch 91/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0208 - val_mean_squared_error: 0.0208 - lr: 0.0010
# Epoch 92/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0199 - val_mean_squared_error: 0.0199 - lr: 0.0010
# Epoch 93/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0286 - mean_squared_error: 0.0286 - val_loss: 0.0197 - val_mean_squared_error: 0.0197 - lr: 0.0010
# Epoch 94/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0284 - mean_squared_error: 0.0284 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - lr: 0.0010
# Epoch 95/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0211 - val_mean_squared_error: 0.0211 - lr: 0.0010
# Epoch 96/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - lr: 0.0010
# Epoch 97/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0285 - mean_squared_error: 0.0285 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - lr: 0.0010
# Epoch 98/100
# 77/77 [==============================] - 1s 14ms/step - loss: 0.0283 - mean_squared_error: 0.0283 - val_loss: 0.0201 - val_mean_squared_error: 0.0201 - lr: 0.0010
# Epoch 99/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0205 - val_mean_squared_error: 0.0205 - lr: 0.0010
# Epoch 100/100
# 77/77 [==============================] - 1s 13ms/step - loss: 0.0281 - mean_squared_error: 0.0281 - val_loss: 0.0194 - val_mean_squared_error: 0.0194 - lr: 0.0010

# %% [markdown]
# # Compute labels and scores

# %%
true_labels = np.asarray(data_test_labels, dtype=np.intc)
labels = model.predict(data, data_test)
scores = model.anomaly_score(data, data_test)
perc = np.sum(labels) / labels.shape[0]

# %% [markdown]
# # Evaluation metrics for anomaly detection

# %%
compute_metrics(true_labels, scores, labels, compute_roc_auc=not CHECK_OVERFITTING, only_roc_auc=False)
# Out:
# ACCURACY SCORE:  0.9895400707583448
# PRECISION SCORE:  0.0
# RECALL SCORE:  0.0
# F1 SCORE:  0.0
# AVERAGE PRECISION SCORE:  0.0015796137145569398
# PRECISION-RECALL AUC SCORE:  0.0011983195254717232
# AUROC SCORE:  0.6844211822660099

# %% [markdown]
# # Confusion matrix

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, labels)
vw.plot_confusion_matrix(confusion_matrix)

# %% [markdown]
# # ROC curve

# %%
vw.plot_roc_curve(true_labels, scores)

# %% [markdown]
# # Precision-recall curve

# %%
vw.plot_precision_recall_curve(true_labels, scores)

# %% [markdown]
# # Assigned labels

# %%
vw.plot_univariate_time_series_predictions(dataframe, labels)

# %% [markdown]
# # Assigned scores

# %%
vw.plot_univariate_time_series_predictions(dataframe, scores)

# %% [markdown]
# # Data and predictions

# %%
predictions = model.predict_time_series(data[validation_slices[0]], data_test)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=True)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=False)

# %% [markdown]
# # Anomalies predictions as red dots

# %%
bars = vw.get_bars_indices_on_test_df(all_df,
                                      dataframe,
                                      PURE_DATA_KEY,
                                      GROUND_WINDOWS_PATH)
vw.plot_time_series_with_predicitons_bars(dataframe,
                                          labels,
                                          bars,
                                          pred_color='r')
