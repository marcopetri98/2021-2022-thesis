# %% [markdown]
# # Imports and constants

# %%
import os

import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

import visualizer.Viewer as vw
from Metrics import compute_metrics, make_metric_plots
from models.time_series.anomaly.deep_learning.CNNAutoencoder import CNNAutoencoder
from reader.NABTimeSeriesReader import NABTimeSeriesReader

# DATASET 1: ambient_temperature_system_failure
# DATASET 2: nyc_taxi
VALIDATION_DIM = 0.19
DATASET_PATH = "data/dataset/"
DATASET = "nyc_taxi.csv"
PURE_DATA_KEY = "realKnownCause/nyc_taxi.csv"
GROUND_WINDOWS_PATH = "data/dataset/combined_windows.json"
# The number of normal samples that must lie between a normal slice and an anomaly
SAFETY_DIM = 50
MINIMUM_SLICE = 100
ALL_METRICS = True
LOAD_MODEL = False
CHECK_OVERFITTING = False
AUTOENCODER_WINDOW = 32


def preprocess(X) -> np.ndarray:
    return StandardScaler().fit_transform(X)

# %% [markdown]
# # Set seed for reproducibility

# %%
np.random.seed(57)
tf.random.set_seed(57)

# %% [markdown]
# # Load training and testing data

# %%
reader = NABTimeSeriesReader(DATASET_PATH)
all_df = reader.read(DATASET_PATH + DATASET).get_dataframe()
training, test = reader.train_test_split(train_perc=0.37).get_train_test_dataframes()

# Data used to train
data = preprocess(np.array(training["value"]).reshape((training["value"].shape[0], 1)))
data_labels = training["target"]

# Data used to test
data_test = preprocess(np.array(test["value"]).reshape((test["value"].shape[0], 1)))
data_test_labels = test["target"]

# Eliminate exceeding points
if data_test.shape[0] % AUTOENCODER_WINDOW != 0:
    remainder_points = data_test.shape[0] % AUTOENCODER_WINDOW
    
    np_data = np.array(data)
    np_data_test = np.array(data_test)
    np_data_labels = np.array(data_labels)
    np_data_test_labels = np.array(data_test_labels)
    data = np.concatenate((np_data, np_data_test[0:remainder_points]))
    data_labels = np.concatenate((np_data_labels, np_data_test_labels[0:remainder_points]))
    data_test = data_test[remainder_points:]
    data_test_labels = data_test_labels[remainder_points:]
    
    np_train = np.concatenate((np.array(training), np.array(test[:remainder_points])))
    training = pd.DataFrame(np_train, columns=training.columns)
    
    np_test = np.array(test[remainder_points:])
    test = pd.DataFrame(np_test, columns=test.columns)

# Data used to evaluate
dataframe = test.copy()
dataframe["value"] = data_test

if CHECK_OVERFITTING:
    data_test = preprocess(np.array(training["value"]).reshape(training["value"].shape[0], 1))
    data_test_labels = training["target"]
    dataframe = training.copy()
    dataframe["value"] = data_test

# %% [markdown]
# # Set slices on which to train and validate
#
# In each case we use a self-supervised approach. The models are built to be able to correctly reproduce normal samples of the data. Therefore, from the training dataset, we want to exclude all possible anomalies and their neighbouring points not to learn anomalies patterns. In such a way, we aim the model to produce big mispredictions for those points that are anomalies. Given these statements, from training and validation set we extract slices without anomalies.

# %%
# Create the slices of the trainig data
change_idx = np.where(np.array(data_labels[:-1]) != np.array(data_labels[1:]))
change_idx = np.array(change_idx) + 1
change_idx = change_idx.reshape(change_idx.shape[1])
change_idx = np.concatenate((np.array([0]), change_idx))
normal_slices = []
anomaly_slices = []
for i in range(len(change_idx)):
    start = change_idx[i]
    if i < len(change_idx) -1:
        stop = change_idx[i+1]
    else:
        stop = data.shape[0]
    
    if data_labels[change_idx[i]] == 1:
        anomaly_slices.append(slice(start, stop))
    else:
        normal_slices.append(slice(start, stop))

print("The slices before safety check: %s" % normal_slices)

for i in range(len(normal_slices)):
    start_first = False
    end_last = False
    if normal_slices[i].start == 0:
        start_first = True
    if normal_slices[i].stop == data.shape[0]:
        end_last = True
    
    if not start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)
    elif not start_first and end_last:
        normal_slices[i] = slice(normal_slices[i].start + SAFETY_DIM,
                                 normal_slices[i].stop,
                                 normal_slices[i].step)
    elif start_first and not end_last:
        normal_slices[i] = slice(normal_slices[i].start,
                                 normal_slices[i].stop - SAFETY_DIM,
                                 normal_slices[i].step)

print("The slices after safety check: %s" % normal_slices)
# Out:
# The slices before safety check: [slice(0, 3824, None)]
# The slices after safety check: [slice(0, 3824, None)]

# %% [markdown]
# # Computation of training and validation slices
#
# Given the slices of normal points on which we will train and validate the model, we need to compute the slices characterizing the training and the validation samples of the dataset. To do so, we will need to iterate over the normal slices to compute the number of points in it. Then, we compute the number of points required for the validation set and from this number we will compute the validation slices. However, we risk to compute slices of only 1 sample in some extreme cases. Therefore, we will control that each slice is at least of `MINIMUM_SLICE` samples.

# %%
# Gets the step (equal for all slices)
step = normal_slices[0].step if normal_slices[0].step is not None else 1
ok_normal_slices = []
tot_samples = 0
for i in range(len(normal_slices)):
    samples = int((normal_slices[i].stop - normal_slices[i].start) / step)
    if samples > MINIMUM_SLICE:
        tot_samples += samples
        ok_normal_slices.append(normal_slices[i])
        
valid_points = tot_samples * VALIDATION_DIM
training_slices = []
validation_slices = []
tot_valid = 0
for i in reversed(range(len(ok_normal_slices))):
    if tot_valid >= valid_points:
        training_slices.append(ok_normal_slices[i])
    else:
        samples = int((ok_normal_slices[i].stop - ok_normal_slices[i].start) / step)
        needed_points = valid_points - tot_valid

        if samples < needed_points:
            validation_slices.append(ok_normal_slices[i])
        else:
            train_stop = int(ok_normal_slices[i].stop - needed_points * step)
            slice_train = slice(ok_normal_slices[i].start,
                                train_stop,
                                ok_normal_slices[i].step)
            slice_valid = slice(train_stop,
                                ok_normal_slices[i].stop,
                                ok_normal_slices[i].step)
            
            # If points are enough, they are added to lists
            if (slice_train.stop - slice_train.start) / step >= MINIMUM_SLICE:
                training_slices.append(slice_train)
            if (slice_valid.stop - slice_valid.start) / step >= MINIMUM_SLICE:
                validation_slices.append(slice_valid)
                
            # Since in this else we enter only at the last slice, set up to exit in case minimum
            # slice is not reached
            tot_valid = valid_points + 1
            
training_slices.reverse()
validation_slices.reverse()

print("The training slices are: %s" % training_slices)
print("The validation slices are: %s" % validation_slices)
# Out:
# The training slices are: [slice(0, 3097, None)]
# The validation slices are: [slice(3097, 3824, None)]

# %% [markdown]
# # Load or fit the model

# %%
model = CNNAutoencoder(window=AUTOENCODER_WINDOW,
                       max_epochs=500,
                       batch_size=32,
                       extend_not_multiple=True,
                       filename="nyc_ae_cnn")
if LOAD_MODEL:
    model.load_model("data/nn_models/nyc_ae_cnn")
else:
    model.fit(data, training_slices, validation_slices, data_labels)
# Out:
# [2022/05/17 19:01:32] WARNING: Data will be modified to match the window size, note that the input must be a multiple of the window size for autoencoders. This is just a comfort utility. You can ignore this warning if no other warnings regarding the training set pop up.
# [2022/05/17 19:01:32] WARNING: On 1th training slice, 25 points have been lost
# [2022/05/17 19:01:32] WARNING: On 1th validation slice, 23 points have been lost
# Model: "cnn_autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input (InputLayer)          [(None, 32, 1)]           0
#
#  encoder_cnn_1 (Conv1D)      (None, 32, 16)            64
#
#  encoder_pool_1 (MaxPooling1  (None, 16, 16)           0
#  D)
#
#  encoder_cnn_2 (Conv1D)      (None, 16, 8)             392
#
#  encoder_pool_2 (MaxPooling1  (None, 8, 8)             0
#  D)
#
#  encoder_cnn_3 (Conv1D)      (None, 8, 8)              200
#
#  decoder_cnn_1 (Conv1DTransp  (None, 8, 8)             200
#  ose)
#
#  decoder_up_1 (UpSampling1D)  (None, 16, 8)            0
#
#  decoder_cnn_2 (Conv1DTransp  (None, 16, 8)            200
#  ose)
#
#  decoder_up_2 (UpSampling1D)  (None, 32, 8)            0
#
#  decoder_cnn_3 (Conv1DTransp  (None, 32, 16)           400
#  ose)
#
#  conv1d (Conv1D)             (None, 32, 1)             49
#
# =================================================================
# Total params: 1,505
# Trainable params: 1,505
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 76/76 [==============================] - 2s 11ms/step - loss: 0.5464 - mean_squared_error: 0.5464 - val_loss: 0.1632 - val_mean_squared_error: 0.1632 - lr: 0.0010
# Epoch 2/500
# 76/76 [==============================] - 1s 6ms/step - loss: 0.1276 - mean_squared_error: 0.1276 - val_loss: 0.0479 - val_mean_squared_error: 0.0479 - lr: 0.0010
# Epoch 3/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0540 - mean_squared_error: 0.0540 - val_loss: 0.0312 - val_mean_squared_error: 0.0312 - lr: 0.0010
# Epoch 4/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0376 - mean_squared_error: 0.0376 - val_loss: 0.0234 - val_mean_squared_error: 0.0234 - lr: 0.0010
# Epoch 5/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0295 - mean_squared_error: 0.0295 - val_loss: 0.0189 - val_mean_squared_error: 0.0189 - lr: 0.0010
# Epoch 6/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0161 - val_mean_squared_error: 0.0161 - lr: 0.0010
# Epoch 7/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0218 - mean_squared_error: 0.0218 - val_loss: 0.0145 - val_mean_squared_error: 0.0145 - lr: 0.0010
# Epoch 8/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0197 - mean_squared_error: 0.0197 - val_loss: 0.0131 - val_mean_squared_error: 0.0131 - lr: 0.0010
# Epoch 9/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0182 - mean_squared_error: 0.0182 - val_loss: 0.0120 - val_mean_squared_error: 0.0120 - lr: 0.0010
# Epoch 10/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0113 - val_mean_squared_error: 0.0113 - lr: 0.0010
# Epoch 11/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0154 - mean_squared_error: 0.0154 - val_loss: 0.0104 - val_mean_squared_error: 0.0104 - lr: 0.0010
# Epoch 12/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0144 - mean_squared_error: 0.0144 - val_loss: 0.0101 - val_mean_squared_error: 0.0101 - lr: 0.0010
# Epoch 13/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0136 - mean_squared_error: 0.0136 - val_loss: 0.0093 - val_mean_squared_error: 0.0093 - lr: 0.0010
# Epoch 14/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0128 - mean_squared_error: 0.0128 - val_loss: 0.0087 - val_mean_squared_error: 0.0087 - lr: 0.0010
# Epoch 15/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0121 - mean_squared_error: 0.0121 - val_loss: 0.0084 - val_mean_squared_error: 0.0084 - lr: 0.0010
# Epoch 16/500
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0115 - mean_squared_error: 0.0115 - val_loss: 0.0079 - val_mean_squared_error: 0.0079 - lr: 0.0010
# Epoch 17/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0078 - val_mean_squared_error: 0.0078 - lr: 0.0010
# Epoch 18/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0074 - val_mean_squared_error: 0.0074 - lr: 0.0010
# Epoch 19/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0101 - mean_squared_error: 0.0101 - val_loss: 0.0072 - val_mean_squared_error: 0.0072 - lr: 0.0010
# Epoch 20/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0099 - mean_squared_error: 0.0099 - val_loss: 0.0070 - val_mean_squared_error: 0.0070 - lr: 0.0010
# Epoch 21/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0094 - mean_squared_error: 0.0094 - val_loss: 0.0065 - val_mean_squared_error: 0.0065 - lr: 0.0010
# Epoch 22/500
# 76/76 [==============================] - 1s 6ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0064 - val_mean_squared_error: 0.0064 - lr: 0.0010
# Epoch 23/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0088 - mean_squared_error: 0.0088 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - lr: 0.0010
# Epoch 24/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0086 - mean_squared_error: 0.0086 - val_loss: 0.0062 - val_mean_squared_error: 0.0062 - lr: 0.0010
# Epoch 25/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0084 - mean_squared_error: 0.0084 - val_loss: 0.0059 - val_mean_squared_error: 0.0059 - lr: 0.0010
# Epoch 26/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0060 - val_mean_squared_error: 0.0060 - lr: 0.0010
# Epoch 27/500
# 76/76 [==============================] - 1s 10ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0058 - val_mean_squared_error: 0.0058 - lr: 0.0010
# Epoch 28/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0057 - val_mean_squared_error: 0.0057 - lr: 0.0010
# Epoch 29/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0078 - mean_squared_error: 0.0078 - val_loss: 0.0056 - val_mean_squared_error: 0.0056 - lr: 0.0010
# Epoch 30/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0055 - val_mean_squared_error: 0.0055 - lr: 0.0010
# Epoch 31/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - lr: 0.0010
# Epoch 32/500
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0074 - mean_squared_error: 0.0074 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - lr: 0.0010
# Epoch 33/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0073 - mean_squared_error: 0.0073 - val_loss: 0.0054 - val_mean_squared_error: 0.0054 - lr: 0.0010
# Epoch 34/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0072 - mean_squared_error: 0.0072 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - lr: 0.0010
# Epoch 35/500
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0052 - val_mean_squared_error: 0.0052 - lr: 0.0010
# Epoch 36/500
# 76/76 [==============================] - 1s 10ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0050 - val_mean_squared_error: 0.0050 - lr: 0.0010
# Epoch 37/500
# 76/76 [==============================] - 1s 11ms/step - loss: 0.0070 - mean_squared_error: 0.0070 - val_loss: 0.0051 - val_mean_squared_error: 0.0051 - lr: 0.0010
# Epoch 38/500
# 76/76 [==============================] - 1s 12ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - lr: 0.0010
# Epoch 39/500
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - lr: 0.0010
# Epoch 40/500
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - lr: 0.0010
# Epoch 41/500
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0067 - mean_squared_error: 0.0067 - val_loss: 0.0049 - val_mean_squared_error: 0.0049 - lr: 0.0010
# Epoch 42/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0065 - mean_squared_error: 0.0065 - val_loss: 0.0048 - val_mean_squared_error: 0.0048 - lr: 0.0010
# Epoch 43/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0064 - mean_squared_error: 0.0064 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - lr: 0.0010
# Epoch 44/500
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - lr: 0.0010
# Epoch 45/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0046 - val_mean_squared_error: 0.0046 - lr: 0.0010
# Epoch 46/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - lr: 0.0010
# Epoch 47/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - lr: 0.0010
# Epoch 48/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0047 - val_mean_squared_error: 0.0047 - lr: 0.0010
# Epoch 49/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0010
# Epoch 50/500
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0060 - mean_squared_error: 0.0060 - val_loss: 0.0044 - val_mean_squared_error: 0.0044 - lr: 0.0010
# Epoch 51/500
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0010
# Epoch 52/500
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0059 - mean_squared_error: 0.0059 - val_loss: 0.0043 - val_mean_squared_error: 0.0043 - lr: 0.0010
# Epoch 53/500
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - lr: 0.0010
# Epoch 54/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0058 - mean_squared_error: 0.0058 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - lr: 0.0010
# Epoch 55/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - lr: 0.0010
# Epoch 56/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - lr: 0.0010
# Epoch 57/500
# 76/76 [==============================] - 1s 11ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0045 - val_mean_squared_error: 0.0045 - lr: 0.0010
# Epoch 58/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0042 - val_mean_squared_error: 0.0042 - lr: 0.0010
# Epoch 59/500
# 76/76 [==============================] - 1s 6ms/step - loss: 0.0057 - mean_squared_error: 0.0057 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - lr: 0.0010
# Epoch 60/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - lr: 0.0010
# Epoch 61/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - lr: 0.0010
# Epoch 62/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - lr: 0.0010
# Epoch 63/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - lr: 0.0010
# Epoch 64/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - lr: 0.0010
# Epoch 65/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - lr: 0.0010
# Epoch 66/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - lr: 0.0010
# Epoch 67/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0053 - mean_squared_error: 0.0053 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - lr: 0.0010
# Epoch 68/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - lr: 0.0010
# Epoch 69/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - lr: 0.0010
# Epoch 70/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - lr: 0.0010
# Epoch 71/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0052 - mean_squared_error: 0.0052 - val_loss: 0.0038 - val_mean_squared_error: 0.0038 - lr: 0.0010
# Epoch 72/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - lr: 0.0010
# Epoch 73/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 74/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 75/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0040 - val_mean_squared_error: 0.0040 - lr: 0.0010
# Epoch 76/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0041 - val_mean_squared_error: 0.0041 - lr: 0.0010
# Epoch 77/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 78/500
# 76/76 [==============================] - 0s 7ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 79/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0039 - val_mean_squared_error: 0.0039 - lr: 0.0010
# Epoch 80/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 81/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 82/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 83/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 84/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0037 - val_mean_squared_error: 0.0037 - lr: 0.0010
# Epoch 85/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 0.0010
# Epoch 86/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 0.0010
# Epoch 87/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 88/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 89/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 0.0010
# Epoch 90/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 0.0010
# Epoch 91/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 92/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 93/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 94/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 0.0010
# Epoch 95/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 96/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 97/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0047 - mean_squared_error: 0.0047 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 98/500
# 76/76 [==============================] - 0s 7ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 99/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 100/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 101/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 102/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 103/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 104/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 105/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 106/500
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 107/500
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 108/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 109/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 110/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 0.0010
# Epoch 111/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 0.0010
# Epoch 112/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 0.0010
# Epoch 113/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 114/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 115/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0036 - val_mean_squared_error: 0.0036 - lr: 0.0010
# Epoch 116/500
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0035 - val_mean_squared_error: 0.0035 - lr: 0.0010
# Epoch 117/500
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 0.0010
# Epoch 118/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 0.0010
# Epoch 119/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0034 - val_mean_squared_error: 0.0034 - lr: 0.0010
# Epoch 120/500
# 76/76 [==============================] - 0s 7ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 0.0010
# Epoch 121/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 122/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 123/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 124/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 125/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 126/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 127/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 128/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 129/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 130/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 131/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 132/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 133/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 134/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 135/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 136/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-04
# Epoch 137/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 138/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 139/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 140/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-04
# Epoch 141/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_squared_error: 0.0033 - lr: 1.0000e-04
# Epoch 142/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 143/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 144/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 145/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 146/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 147/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 148/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 149/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 150/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 151/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 152/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 153/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 154/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 155/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 156/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 157/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 158/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 159/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 160/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 161/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-05
# Epoch 162/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 163/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 164/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 165/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 166/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 167/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 168/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 169/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 170/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 171/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 172/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 173/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 174/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 175/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 176/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 177/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 178/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 179/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 180/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 181/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-06
# Epoch 182/500
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 183/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 184/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 185/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 186/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 187/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 188/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 189/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 190/500
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07
# Epoch 191/500
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042 - mean_squared_error: 0.0042 - val_loss: 0.0032 - val_mean_squared_error: 0.0032 - lr: 1.0000e-07

# %% [markdown]
# # Compute labels and scores

# %%
true_labels = np.asarray(data_test_labels, dtype=np.intc)
labels = model.predict(data, data_test)
scores = model.anomaly_score(data, data_test)
perc = np.sum(labels) / labels.shape[0]

# %% [markdown]
# # Evaluation metrics for anomaly detection

# %%
compute_metrics(true_labels, scores, labels, compute_roc_auc=not CHECK_OVERFITTING, only_roc_auc=False)
# Out:
# ACCURACY SCORE:  0.9933805418719212
# PRECISION SCORE:  0.0
# RECALL SCORE:  0.0
# F1 SCORE:  0.0
# AVERAGE PRECISION SCORE:  0.0007061658871832766
# PRECISION-RECALL AUC SCORE:  0.0005595055529580594
# AUROC SCORE:  0.35455245724849793

# %% [markdown]
# # Confusion matrix

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, labels)
vw.plot_confusion_matrix(confusion_matrix)

# %% [markdown]
# # ROC curve

# %%
vw.plot_roc_curve(true_labels, scores)

# %% [markdown]
# # Precision-recall curve

# %%
vw.plot_precision_recall_curve(true_labels, scores)

# %% [markdown]
# # Assigned labels

# %%
vw.plot_univariate_time_series_predictions(dataframe, labels)

# %% [markdown]
# # Assigned scores

# %%
vw.plot_univariate_time_series_predictions(dataframe, scores)

# %% [markdown]
# # Data and predictions

# %%
predictions = model.predict_time_series(data[validation_slices[0]], data_test)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=True)
vw.plot_time_series_forecast(data_test, predictions, on_same_plot=False)

# %% [markdown]
# # Anomalies predictions as red dots

# %%
bars = vw.get_bars_indices_on_test_df(all_df,
                                      dataframe,
                                      PURE_DATA_KEY,
                                      GROUND_WINDOWS_PATH)
vw.plot_time_series_with_predicitons_bars(dataframe,
                                          labels,
                                          bars,
                                          pred_color='r')
