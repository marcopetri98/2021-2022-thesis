# %% [markdown]
# # Imports and constants

# %%
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn import metrics

from Metrics import compute_metrics, make_metric_plots
import visualizer.Viewer as vw
from models.time_series.anomaly.statistical.TimeSeriesAnomalyARIMA import TimeSeriesAnomalyARIMA
from reader.NABTimeSeriesReader import NABTimeSeriesReader

# DATASET 1: ambient_temperature_system_failure
# DATASET 2: nyc_taxi
DATASET_PATH = "data/dataset/"
DATASET = "nyc_taxi.csv"
PURE_DATA_KEY = "realKnownCause/nyc_taxi.csv"
GROUND_WINDOWS_PATH = "data/dataset/combined_windows.json"
CHECK_OVERFITTING = False
ALL_DATA = False

def preprocess(X) -> np.ndarray:
    return StandardScaler().fit_transform(X)

# %% [markdown]
# # Read the dataset and train-test split

# %%
reader = NABTimeSeriesReader(DATASET_PATH)
all_df = reader.read(DATASET_PATH + DATASET).get_dataframe()
training, test = reader.train_test_split(train_perc=0.37).get_train_test_dataframes()

# Data used to train
data = preprocess(np.array(training["value"]).reshape((training["value"].shape[0], 1)))
data_labels = training["target"]

# Data used to test
data_test = preprocess(np.array(test["value"]).reshape((test["value"].shape[0], 1)))
data_test_labels = test["target"]

# Dataframe used to evaluate
dataframe = test.copy()
dataframe["value"] = data_test

train = data

if CHECK_OVERFITTING:
    data_test = data
    data_test_labels = data_labels
    dataframe = training.copy()
    dataframe["value"] = data_test
elif ALL_DATA:
    data_test = preprocess(np.array(all_df["value"]).reshape(all_df["value"].shape[0], 1))
    data_test_labels = all_df["target"]
    dataframe = all_df.copy()
    dataframe["value"] = data_test

# %% [markdown]
# # Create model, classify and score

# %%
model = TimeSeriesAnomalyARIMA(scoring="difference",
                               endog=train,
                               order=(0, 0, 8),
                               seasonal_order=(0, 0, 0, 0),
                               trend="n")
model.fit(fit_params={"method":"innovations_mle",
                      "gls":True})

true_labels = data_test_labels

labels = model.classify(data_test.reshape((-1, 1)), data.reshape((-1, 1)))
scores = model.anomaly_score(data_test.reshape((-1, 1)), data.reshape((-1, 1)))
# Out:
# ==========================
# = Start of the model fit =
# ==========================
# [2022/05/17 14:24:02] Execution: Start to learn the parameters
# [2022/05/17 14:24:07] Execution: Parameters have been learnt
# [2022/05/17 14:24:07] Execution: Start to compute predictions of the test set
# [2022/05/17 14:24:07] Execution: Test set has been predicted
# [2022/05/17 14:24:07] Execution: Start to compute prediction errors
# [2022/05/17 14:24:07] Execution: Prediction errors have been computed
# [2022/05/17 14:24:07] Execution: Start to compute the threshold on the validation data
# [2022/05/17 14:24:07] Execution: Threshold has been computed
# [2022/05/17 14:24:07] Execution: The model has been trained and the results are:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 3438
# Model:                 ARIMA(0, 0, 8)   Log Likelihood                1040.086
# Date:                Tue, 17 May 2022   AIC                          -2062.172
# Time:                        14:24:07   BIC                          -2006.912
# Sample:                             0   HQIC                         -2042.430
#                                - 3438
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1          1.5199      0.019     79.191      0.000       1.482       1.557
# ma.L2          2.8582      0.064     44.747      0.000       2.733       2.983
# ma.L3          3.5563      0.098     36.277      0.000       3.364       3.748
# ma.L4          3.3851      0.107     31.586      0.000       3.175       3.595
# ma.L5          2.5869      0.098     26.263      0.000       2.394       2.780
# ma.L6          2.0446      0.085     24.046      0.000       1.878       2.211
# ma.L7          1.3319      0.049     26.991      0.000       1.235       1.429
# ma.L8          0.6177      0.024     25.967      0.000       0.571       0.664
# sigma2         0.0132      0.001     14.823      0.000       0.011       0.015
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.48   Jarque-Bera (JB):              3421.82
# Prob(Q):                              0.03   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.61   Skew:                             0.35
# Prob(H) (two-sided):                  0.00   Kurtosis:                         7.84
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2022/05/17 14:24:07] Execution: The learnt threshold is 0.508340721119382
# ========================
# = End of the model fit =
# ========================
# ============================
# = Start to classify points =
# ============================
# [2022/05/17 14:24:07] Execution: Start to compute predictions of the test set
# [2022/05/17 14:24:07] Execution: Test set has been predicted
# [2022/05/17 14:24:07] Execution: Start to compute prediction errors
# [2022/05/17 14:24:07] Execution: Prediction errors have been computed
# [2022/05/17 14:24:07] Execution: Evaluate point on their prediction error
# ================================
# = Points' classification ended =
# ================================
# ============================================
# = Start to compute anomaly score of points =
# ============================================
# [2022/05/17 14:24:07] Execution: Start to compute predictions of the test set
# [2022/05/17 14:24:07] Execution: Test set has been predicted
# [2022/05/17 14:24:07] Execution: Evaluate scores on the basis of prediction error
# =============================================
# = Anomaly score of points computation ended =
# =============================================

# %% [markdown]
# # Evaluation metrics for anomaly detection

# %%
compute_metrics(true_labels, scores, labels, only_roc_auc=False)
# Out:
# ACCURACY SCORE:  0.9886171358252577
# PRECISION SCORE:  0.014084507042253521
# RECALL SCORE:  0.2
# F1 SCORE:  0.02631578947368421
# AVERAGE PRECISION SCORE:  0.02945789226051674
# PRECISION-RECALL AUC SCORE:  0.01502641142799776
# AUROC SCORE:  0.5993842364532019

# %% [markdown]
# # Confusion matrix

# %%
confusion_matrix = metrics.confusion_matrix(true_labels, labels)
vw.plot_confusion_matrix(confusion_matrix)

# %% [markdown]
# # ROC curve

# %%
vw.plot_roc_curve(true_labels, scores)

# %% [markdown]
# # Precision-recall curve

# %%
vw.plot_precision_recall_curve(true_labels, scores)

# %% [markdown]
# # Assigned labels

# %%
vw.plot_univariate_time_series_predictions(dataframe, labels)

# %% [markdown]
# # Assigned scores

# %%
vw.plot_univariate_time_series_predictions(dataframe, scores)

# %% [markdown]
# # Anomalies predictions as red dots

# %%
bars = vw.get_bars_indices_on_test_df(all_df,
                                      dataframe,
                                      PURE_DATA_KEY,
                                      GROUND_WINDOWS_PATH)
vw.plot_time_series_with_predicitons_bars(dataframe,
                                          labels,
                                          bars,
                                          pred_color='r')
